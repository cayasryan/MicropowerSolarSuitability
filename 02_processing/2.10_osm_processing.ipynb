# %% [markdown]
# # Power Lines

# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd

place = "Philippines"

power_lines = ox.features_from_place(place, tags={"power": "line"})
# Out:
# /data/students/ryan/anaconda3/envs/capstone_venv/lib/python3.13/site-packages/osmnx/_overpass.py:267: UserWarning: This area is 638 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)

# %%
power_lines
# Out:
#                                                               geometry power  \
# element id
# node    10779220168                         POINT (123.87755 10.31212)  line
#         10835711982                          POINT (121.10441 13.8869)  line
#         10835711991                         POINT (121.10414 13.88624)  line
# way     25777205     LINESTRING (121.2264 14.03493, 121.22894 14.03...  line
#         25777205     LINESTRING (121.2264 14.03493, 121.22894 14.03...  line
# ...                                                                ...   ...
#         1385091402   LINESTRING (120.21961 14.95878, 120.2196 14.95...  line
#         1385091403   LINESTRING (120.21995 14.96075, 120.22011 14.9...  line
#         1385091404   LINESTRING (120.22011 14.96102, 120.2204 14.96...  line
#         1385091405   LINESTRING (120.21853 14.95821, 120.2186 14.95...  line
#         1385091406   LINESTRING (120.21853 14.95821, 120.21817 14.9...  line
#
#                     source design  \
# element id
# node    10779220168    NaN    NaN
#         10835711982    NaN    NaN
#         10835711991    NaN    NaN
# way     25777205      Bing    NaN
#         25777205      Bing    NaN
# ...                    ...    ...
#         1385091402     NaN    NaN
#         1385091403     NaN    NaN
#         1385091404     NaN    NaN
#         1385091405     NaN    NaN
#         1385091406     NaN    NaN
#
#                                                          operator  \
# element id
# node    10779220168                              Visayan Electric
#         10835711982              Batangas II Electric Cooperative
#         10835711991              Batangas II Electric Cooperative
# way     25777205     National Grid Corporation of the Philippines
#         25777205     National Grid Corporation of the Philippines
# ...                                                           ...
#         1385091402   National Grid Corporation of the Philippines
#         1385091403                   Santa Cruz Solar Energy Inc.
#         1385091404                   Santa Cruz Solar Energy Inc.
#         1385091405                            AP Renewables, Inc.
#         1385091406                            AP Renewables, Inc.
#
#                     operator:short operator:wikidata  \
# element id
# node    10779220168            NaN          Q7935617
#         10835711982            NaN               NaN
#         10835711991            NaN               NaN
# way     25777205              NGCP         Q28197109
#         25777205              NGCP         Q28197109
# ...                            ...               ...
#         1385091402            NGCP         Q28197109
#         1385091403           SCSEI               NaN
#         1385091404           SCSEI               NaN
#         1385091405             NaN               NaN
#         1385091406             NaN               NaN
#
#                                                             ref rating  \
# element id
# node    10779220168                                         NaN    NaN
#         10835711982                                         NaN    NaN
#         10835711991                                         NaN    NaN
# way     25777205     (9LI1ILJ-TAY)ALM-TAY; (9LI1DAS-TAY)ALM-TAY    NaN
#         25777205     (9LI1ILJ-TAY)ALM-TAY; (9LI1DAS-TAY)ALM-TAY    NaN
# ...                                                         ...    ...
#         1385091402                                          NaN    NaN
#         1385091403                                          NaN    NaN
#         1385091404                                          NaN    NaN
#         1385091405                                          NaN    NaN
#         1385091406                                          NaN    NaN
#
#                     voltage:primary  ... tower_to_tower_distance  \
# element id                           ...
# node    10779220168             NaN  ...                     NaN
#         10835711982             NaN  ...                     NaN
#         10835711991             NaN  ...                     NaN
# way     25777205                NaN  ...                     NaN
#         25777205                NaN  ...                     NaN
# ...                             ...  ...                     ...
#         1385091402              NaN  ...                     NaN
#         1385091403              NaN  ...                     NaN
#         1385091404              NaN  ...                     NaN
#         1385091405              NaN  ...                     NaN
#         1385091406              NaN  ...                     NaN
#
#                     year_of_construction:NGCP year_of_construction:TransCo  \
# element id
# node    10779220168                       NaN                          NaN
#         10835711982                       NaN                          NaN
#         10835711991                       NaN                          NaN
# way     25777205                          NaN                          NaN
#         25777205                          NaN                          NaN
# ...                                       ...                          ...
#         1385091402                        NaN                          NaN
#         1385091403                        NaN                          NaN
#         1385091404                        NaN                          NaN
#         1385091405                        NaN                          NaN
#         1385091406                        NaN                          NaN
#
#                     communication lanes owner:type cable  cab circuit level
# element id
# node    10779220168           NaN   NaN        NaN   NaN  NaN     NaN   NaN
#         10835711982           NaN   NaN        NaN   NaN  NaN     NaN   NaN
#         10835711991           NaN   NaN        NaN   NaN  NaN     NaN   NaN
# way     25777205              NaN   NaN        NaN   NaN  NaN     NaN   NaN
#         25777205              NaN   NaN        NaN   NaN  NaN     NaN   NaN
# ...                           ...   ...        ...   ...  ...     ...   ...
#         1385091402            NaN   NaN        NaN   NaN  NaN     NaN   NaN
#         1385091403            NaN   NaN        NaN   NaN  NaN     NaN   NaN
#         1385091404            NaN   NaN        NaN   NaN  NaN     NaN   NaN
#         1385091405            NaN   NaN        NaN   NaN  NaN     NaN   NaN
#         1385091406            NaN   NaN        NaN   NaN  NaN     NaN   NaN
#
# [3758 rows x 60 columns]

# %%
power_lines.to_file("../00_data/power_lines.geojson", driver="GeoJSON")

# %%
power_lines = power_lines['geometry']['way']

# %%
file_path = "../01_processed_data/philippines_power_lines.geojson"

power_lines = power_lines.to_crs(epsg=32651)

# Save only the geometry to a GeoJSON file
power_lines.to_file(file_path, driver="GeoJSON")

# %% [markdown]
# ## Power Features
#
# Not Just Power Lines

# %%
tags = {
    "power": ["line", "minor_line", "substation", "plant", "generator"]
}
power_features = ox.features_from_place("Philippines", tags=tags)
# Out:
# /data/students/ryan/anaconda3/envs/capstone_venv/lib/python3.13/site-packages/osmnx/_overpass.py:267: UserWarning: This area is 638 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)

# %%
power_features.geometry.id
# Out:
# element  id
# node     410401292                            POINT (123.43238 10.51621)
#          899383380                            POINT (124.27269 11.56762)
#          1137432767                            POINT (120.69356 18.5293)
#          1137432774                           POINT (120.69974 18.52881)
#          1137432776                           POINT (120.71511 18.52831)
#                                              ...
# way      1385091402    LINESTRING (120.21961 14.95878, 120.2196 14.95...
#          1385091403    LINESTRING (120.21995 14.96075, 120.22011 14.9...
#          1385091404    LINESTRING (120.22011 14.96102, 120.2204 14.96...
#          1385091405    LINESTRING (120.21853 14.95821, 120.2186 14.95...
#          1385091406    LINESTRING (120.21853 14.95821, 120.21817 14.9...
# Name: geometry, Length: 27791, dtype: geometry

# %%
power_features
# Out:
#                                                              geometry  \
# element id
# node    410401292                          POINT (123.43238 10.51621)
#         899383380                          POINT (124.27269 11.56762)
#         1137432767                          POINT (120.69356 18.5293)
#         1137432774                         POINT (120.69974 18.52881)
#         1137432776                         POINT (120.71511 18.52831)
# ...                                                               ...
# way     1385091402  LINESTRING (120.21961 14.95878, 120.2196 14.95...
#         1385091403  LINESTRING (120.21995 14.96075, 120.22011 14.9...
#         1385091404  LINESTRING (120.22011 14.96102, 120.2204 14.96...
#         1385091405  LINESTRING (120.21853 14.95821, 120.2186 14.95...
#         1385091406  LINESTRING (120.21853 14.95821, 120.21817 14.9...
#
#                    generator:method generator:source operator:type  \
# element id
# node    410401292               NaN              NaN           NaN
#         899383380               NaN           diesel           NaN
#         1137432767     wind_turbine             wind           NaN
#         1137432774     wind_turbine             wind           NaN
#         1137432776     wind_turbine             wind           NaN
# ...                             ...              ...           ...
# way     1385091402              NaN              NaN           NaN
#         1385091403              NaN              NaN           NaN
#         1385091404              NaN              NaN           NaN
#         1385091405              NaN              NaN           NaN
#         1385091406              NaN              NaN           NaN
#
#                          power building                           name  \
# element id
# node    410401292   substation      NaN              Power Transformer
#         899383380    generator      NaN  Higatangan Diesel Power Plant
#         1137432767   generator      NaN                            NaN
#         1137432774   generator      NaN                            NaN
#         1137432776   generator      NaN                            NaN
# ...                        ...      ...                            ...
# way     1385091402        line      NaN             Castillejos–Balsik
#         1385091403        line      NaN     SanMar Solar - Castillejos
#         1385091404        line      NaN     SanMar Solar - Castillejos
#         1385091405        line      NaN                            NaN
#         1385091406        line      NaN                            NaN
#
#                                                         operator  \
# element id
# node    410401292                                         VRESCO
#         899383380                                         BILECO
#         1137432767                                           NaN
#         1137432774                                           NaN
#         1137432776                                           NaN
# ...                                                          ...
# way     1385091402  National Grid Corporation of the Philippines
#         1385091403                  Santa Cruz Solar Energy Inc.
#         1385091404                  Santa Cruz Solar Energy Inc.
#         1385091405                           AP Renewables, Inc.
#         1385091406                           AP Renewables, Inc.
#
#                                                                source  \
# element id
# node    410401292   San Carlos City (http://www.sancarloscity.gov....
#         899383380                                                 NaN
#         1137432767                                               Bing
#         1137432774                                               Bing
#         1137432776                                               Bing
# ...                                                               ...
# way     1385091402                                                NaN
#         1385091403                                                NaN
#         1385091404                                                NaN
#         1385091405                                                NaN
#         1385091406                                                NaN
#
#                    description  ... tunnel fenced source_ref  \
# element id                      ...
# node    410401292          NaN  ...    NaN    NaN        NaN
#         899383380          NaN  ...    NaN    NaN        NaN
#         1137432767         NaN  ...    NaN    NaN        NaN
#         1137432774         NaN  ...    NaN    NaN        NaN
#         1137432776         NaN  ...    NaN    NaN        NaN
# ...                        ...  ...    ...    ...        ...
# way     1385091402         NaN  ...    NaN    NaN        NaN
#         1385091403         NaN  ...    NaN    NaN        NaN
#         1385091404         NaN  ...    NaN    NaN        NaN
#         1385091405         NaN  ...    NaN    NaN        NaN
#         1385091406         NaN  ...    NaN    NaN        NaN
#
#                    plant:output:heat plant:output:steam is_in  \
# element id
# node    410401292                NaN                NaN   NaN
#         899383380                NaN                NaN   NaN
#         1137432767               NaN                NaN   NaN
#         1137432774               NaN                NaN   NaN
#         1137432776               NaN                NaN   NaN
# ...                              ...                ...   ...
# way     1385091402               NaN                NaN   NaN
#         1385091403               NaN                NaN   NaN
#         1385091404               NaN                NaN   NaN
#         1385091405               NaN                NaN   NaN
#         1385091406               NaN                NaN   NaN
#
#                    operator:1995-2010 operator:2010-2020  \
# element id
# node    410401292                 NaN                NaN
#         899383380                 NaN                NaN
#         1137432767                NaN                NaN
#         1137432774                NaN                NaN
#         1137432776                NaN                NaN
# ...                               ...                ...
# way     1385091402                NaN                NaN
#         1385091403                NaN                NaN
#         1385091404                NaN                NaN
#         1385091405                NaN                NaN
#         1385091406                NaN                NaN
#
#                    building:levels:underground is_in:province
# element id
# node    410401292                          NaN            NaN
#         899383380                          NaN            NaN
#         1137432767                         NaN            NaN
#         1137432774                         NaN            NaN
#         1137432776                         NaN            NaN
# ...                                        ...            ...
# way     1385091402                         NaN            NaN
#         1385091403                         NaN            NaN
#         1385091404                         NaN            NaN
#         1385091405                         NaN            NaN
#         1385091406                         NaN            NaN
#
# [27791 rows x 197 columns]

# %%
power_features['power']['node']
# Out:
# id
# 410401292      substation
# 899383380       generator
# 1137432767      generator
# 1137432774      generator
# 1137432776      generator
#                   ...
# 12589627358     generator
# 12641192165     generator
# 12718941554     generator
# 12718941555     generator
# 12718941556     generator
# Name: power, Length: 522, dtype: object

# %%
power_subset = power_features.reset_index()
power_subset
# Out:
#       element          id                                           geometry  \
# 0        node   410401292                         POINT (123.43238 10.51621)
# 1        node   899383380                         POINT (124.27269 11.56762)
# 2        node  1137432767                          POINT (120.69356 18.5293)
# 3        node  1137432774                         POINT (120.69974 18.52881)
# 4        node  1137432776                         POINT (120.71511 18.52831)
# ...       ...         ...                                                ...
# 27786     way  1385091402  LINESTRING (120.21961 14.95878, 120.2196 14.95...
# 27787     way  1385091403  LINESTRING (120.21995 14.96075, 120.22011 14.9...
# 27788     way  1385091404  LINESTRING (120.22011 14.96102, 120.2204 14.96...
# 27789     way  1385091405  LINESTRING (120.21853 14.95821, 120.2186 14.95...
# 27790     way  1385091406  LINESTRING (120.21853 14.95821, 120.21817 14.9...
#
#       generator:method generator:source operator:type       power building  \
# 0                  NaN              NaN           NaN  substation      NaN
# 1                  NaN           diesel           NaN   generator      NaN
# 2         wind_turbine             wind           NaN   generator      NaN
# 3         wind_turbine             wind           NaN   generator      NaN
# 4         wind_turbine             wind           NaN   generator      NaN
# ...                ...              ...           ...         ...      ...
# 27786              NaN              NaN           NaN        line      NaN
# 27787              NaN              NaN           NaN        line      NaN
# 27788              NaN              NaN           NaN        line      NaN
# 27789              NaN              NaN           NaN        line      NaN
# 27790              NaN              NaN           NaN        line      NaN
#
#                                 name  \
# 0                  Power Transformer
# 1      Higatangan Diesel Power Plant
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 27786             Castillejos–Balsik
# 27787     SanMar Solar - Castillejos
# 27788     SanMar Solar - Castillejos
# 27789                            NaN
# 27790                            NaN
#
#                                            operator  ... tunnel fenced  \
# 0                                            VRESCO  ...    NaN    NaN
# 1                                            BILECO  ...    NaN    NaN
# 2                                               NaN  ...    NaN    NaN
# 3                                               NaN  ...    NaN    NaN
# 4                                               NaN  ...    NaN    NaN
# ...                                             ...  ...    ...    ...
# 27786  National Grid Corporation of the Philippines  ...    NaN    NaN
# 27787                  Santa Cruz Solar Energy Inc.  ...    NaN    NaN
# 27788                  Santa Cruz Solar Energy Inc.  ...    NaN    NaN
# 27789                           AP Renewables, Inc.  ...    NaN    NaN
# 27790                           AP Renewables, Inc.  ...    NaN    NaN
#
#       source_ref plant:output:heat plant:output:steam is_in  \
# 0            NaN               NaN                NaN   NaN
# 1            NaN               NaN                NaN   NaN
# 2            NaN               NaN                NaN   NaN
# 3            NaN               NaN                NaN   NaN
# 4            NaN               NaN                NaN   NaN
# ...          ...               ...                ...   ...
# 27786        NaN               NaN                NaN   NaN
# 27787        NaN               NaN                NaN   NaN
# 27788        NaN               NaN                NaN   NaN
# 27789        NaN               NaN                NaN   NaN
# 27790        NaN               NaN                NaN   NaN
#
#       operator:1995-2010 operator:2010-2020 building:levels:underground  \
# 0                    NaN                NaN                         NaN
# 1                    NaN                NaN                         NaN
# 2                    NaN                NaN                         NaN
# 3                    NaN                NaN                         NaN
# 4                    NaN                NaN                         NaN
# ...                  ...                ...                         ...
# 27786                NaN                NaN                         NaN
# 27787                NaN                NaN                         NaN
# 27788                NaN                NaN                         NaN
# 27789                NaN                NaN                         NaN
# 27790                NaN                NaN                         NaN
#
#       is_in:province
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 27786            NaN
# 27787            NaN
# 27788            NaN
# 27789            NaN
# 27790            NaN
#
# [27791 rows x 199 columns]

# %%
power_subset[power_subset['power'] == 'plant']
# Out:
# 280          None
# 510          None
# 523        650 MW
# 525      172.5 MW
# 526      172.5 MW
#            ...
# 27352        None
# 27355     3.44 MW
# 27408        None
# 27423        None
# 27469         yes
# Name: plant:output:electricity, Length: 219, dtype: object

# %%
power_subset['power'].value_counts()
# Out:
# power
# generator     21299
# line           3758
# minor_line     1656
# substation      859
# plant           219
# Name: count, dtype: int64

# %%
power_subset['generator:method'].value_counts()
# Out:
# generator:method
# photovoltaic        20565
# wind_turbine          223
# yes                   188
# combustion            158
# water-storage          11
# run-of-the-river       10
# thermal                 3
# fission                 1
# steam_turbine           1
# Name: count, dtype: int64

# %%
power_subset[['id','power','generator:method','geometry']]
# Out:
#                id       power generator:method  \
# 0       410401292  substation              NaN
# 1       899383380   generator              NaN
# 2      1137432767   generator     wind_turbine
# 3      1137432774   generator     wind_turbine
# 4      1137432776   generator     wind_turbine
# ...           ...         ...              ...
# 27786  1385091402        line              NaN
# 27787  1385091403        line              NaN
# 27788  1385091404        line              NaN
# 27789  1385091405        line              NaN
# 27790  1385091406        line              NaN
#
#                                                 geometry
# 0                             POINT (123.43238 10.51621)
# 1                             POINT (124.27269 11.56762)
# 2                              POINT (120.69356 18.5293)
# 3                             POINT (120.69974 18.52881)
# 4                             POINT (120.71511 18.52831)
# ...                                                  ...
# 27786  LINESTRING (120.21961 14.95878, 120.2196 14.95...
# 27787  LINESTRING (120.21995 14.96075, 120.22011 14.9...
# 27788  LINESTRING (120.22011 14.96102, 120.2204 14.96...
# 27789  LINESTRING (120.21853 14.95821, 120.2186 14.95...
# 27790  LINESTRING (120.21853 14.95821, 120.21817 14.9...
#
# [27791 rows x 4 columns]

# %%
grid_elements = power_subset[power_subset['power'].isin(['line', 'substation','minor_line'])]
grid_elements.reset_index(drop=True, inplace=True)
grid_elements
# Out:
#       index element          id generator:method generator:source  \
# 0         0    node   410401292             None             None
# 1        20    node  1226388483             None             None
# 2        24    node  1305087249             None             None
# 3        26    node  1305952685             None             None
# 4        27    node  1306727319             None             None
# ...     ...     ...         ...              ...              ...
# 6268  27786     way  1385091402             None             None
# 6269  27787     way  1385091403             None             None
# 6270  27788     way  1385091404             None             None
# 6271  27789     way  1385091405             None             None
# 6272  27790     way  1385091406             None             None
#
#      operator:type       power building                        name  \
# 0             None  substation     None           Power Transformer
# 1             None  substation     None   Dasureco Electric Company
# 2             None  substation     None                        None
# 3             None  substation     None                        None
# 4             None  substation     None           Bitas Sub-Station
# ...            ...         ...      ...                         ...
# 6268          None        line     None          Castillejos–Balsik
# 6269          None        line     None  SanMar Solar - Castillejos
# 6270          None        line     None  SanMar Solar - Castillejos
# 6271          None        line     None                        None
# 6272          None        line     None                        None
#
#                                           operator  ... fenced source_ref  \
# 0                                           VRESCO  ...   None       None
# 1                                             None  ...   None       None
# 2                                             None  ...   None       None
# 3                                             None  ...   None       None
# 4                                             None  ...   None       None
# ...                                            ...  ...    ...        ...
# 6268  National Grid Corporation of the Philippines  ...   None       None
# 6269                  Santa Cruz Solar Energy Inc.  ...   None       None
# 6270                  Santa Cruz Solar Energy Inc.  ...   None       None
# 6271                           AP Renewables, Inc.  ...   None       None
# 6272                           AP Renewables, Inc.  ...   None       None
#
#      plant:output:heat plant:output:steam is_in operator:1995-2010  \
# 0                 None               None  None               None
# 1                 None               None  None               None
# 2                 None               None  None               None
# 3                 None               None  None               None
# 4                 None               None  None               None
# ...                ...                ...   ...                ...
# 6268              None               None  None               None
# 6269              None               None  None               None
# 6270              None               None  None               None
# 6271              None               None  None               None
# 6272              None               None  None               None
#
#      operator:2010-2020 building:levels:underground is_in:province  \
# 0                  None                        None           None
# 1                  None                        None           None
# 2                  None                        None           None
# 3                  None                        None           None
# 4                  None                        None           None
# ...                 ...                         ...            ...
# 6268               None                        None           None
# 6269               None                        None           None
# 6270               None                        None           None
# 6271               None                        None           None
# 6272               None                        None           None
#
#                                                geometry
# 0                            POINT (123.43238 10.51621)
# 1                             POINT (125.23972 6.75418)
# 2                             POINT (125.60608 7.08584)
# 3                                POINT (125.60831 7.07)
# 4                            POINT (120.97998 15.49789)
# ...                                                 ...
# 6268  LINESTRING (120.21961 14.95878, 120.2196 14.95...
# 6269  LINESTRING (120.21995 14.96075, 120.22011 14.9...
# 6270  LINESTRING (120.22011 14.96102, 120.2204 14.96...
# 6271  LINESTRING (120.21853 14.95821, 120.2186 14.95...
# 6272  LINESTRING (120.21853 14.95821, 120.21817 14.9...
#
# [6273 rows x 200 columns]

# %%
file_path = "../01_processed_data/philippines_grid.geojson"

grid_elements = grid_elements.to_crs(epsg=32651)

# Save only the geometry to a GeoJSON file
grid_elements[['id','power','geometry']].to_file(file_path, driver="GeoJSON")

# %% [markdown]
# ## Solar Sites

# %%
import geopandas as gpd
power_features = gpd.read_file("../00_data/power_features.geojson")
# Out:
# /data/students/ryan/anaconda3/envs/capstone_venv/lib/python3.13/site-packages/pyogrio/raw.py:198: RuntimeWarning: Several features with id = 2542048169 have been found. Altering it to be unique. This warning will not be emitted anymore for this layer
#   return ogr_read(

# %%
power_subset = power_features.reset_index()
power_subset
# Out:
#        index element          id generator:method generator:source  \
# 0          0    node   410401292             None             None
# 1          1    node   899383380             None           diesel
# 2          2    node  1137432767     wind_turbine             wind
# 3          3    node  1137432774     wind_turbine             wind
# 4          4    node  1137432776     wind_turbine             wind
# ...      ...     ...         ...              ...              ...
# 27786  27786     way  1385091402             None             None
# 27787  27787     way  1385091403             None             None
# 27788  27788     way  1385091404             None             None
# 27789  27789     way  1385091405             None             None
# 27790  27790     way  1385091406             None             None
#
#       operator:type       power building                           name  \
# 0              None  substation     None              Power Transformer
# 1              None   generator     None  Higatangan Diesel Power Plant
# 2              None   generator     None                           None
# 3              None   generator     None                           None
# 4              None   generator     None                           None
# ...             ...         ...      ...                            ...
# 27786          None        line     None             Castillejos–Balsik
# 27787          None        line     None     SanMar Solar - Castillejos
# 27788          None        line     None     SanMar Solar - Castillejos
# 27789          None        line     None                           None
# 27790          None        line     None                           None
#
#                                            operator  ... fenced source_ref  \
# 0                                            VRESCO  ...   None       None
# 1                                            BILECO  ...   None       None
# 2                                              None  ...   None       None
# 3                                              None  ...   None       None
# 4                                              None  ...   None       None
# ...                                             ...  ...    ...        ...
# 27786  National Grid Corporation of the Philippines  ...   None       None
# 27787                  Santa Cruz Solar Energy Inc.  ...   None       None
# 27788                  Santa Cruz Solar Energy Inc.  ...   None       None
# 27789                           AP Renewables, Inc.  ...   None       None
# 27790                           AP Renewables, Inc.  ...   None       None
#
#       plant:output:heat plant:output:steam is_in operator:1995-2010  \
# 0                  None               None  None               None
# 1                  None               None  None               None
# 2                  None               None  None               None
# 3                  None               None  None               None
# 4                  None               None  None               None
# ...                 ...                ...   ...                ...
# 27786              None               None  None               None
# 27787              None               None  None               None
# 27788              None               None  None               None
# 27789              None               None  None               None
# 27790              None               None  None               None
#
#       operator:2010-2020 building:levels:underground is_in:province  \
# 0                   None                        None           None
# 1                   None                        None           None
# 2                   None                        None           None
# 3                   None                        None           None
# 4                   None                        None           None
# ...                  ...                         ...            ...
# 27786               None                        None           None
# 27787               None                        None           None
# 27788               None                        None           None
# 27789               None                        None           None
# 27790               None                        None           None
#
#                                                 geometry
# 0                             POINT (123.43238 10.51621)
# 1                             POINT (124.27269 11.56762)
# 2                              POINT (120.69356 18.5293)
# 3                             POINT (120.69974 18.52881)
# 4                             POINT (120.71511 18.52831)
# ...                                                  ...
# 27786  LINESTRING (120.21961 14.95878, 120.2196 14.95...
# 27787  LINESTRING (120.21995 14.96075, 120.22011 14.9...
# 27788  LINESTRING (120.22011 14.96102, 120.2204 14.96...
# 27789  LINESTRING (120.21853 14.95821, 120.2186 14.95...
# 27790  LINESTRING (120.21853 14.95821, 120.21817 14.9...
#
# [27791 rows x 200 columns]

# %%
power_subset[power_subset['power'] == 'plant']['plant:source'].value_counts()
# Out:
# plant:source
# solar         78
# coal          28
# hydro         26
# diesel        22
# geothermal    14
# oil            9
# biomass        7
# gas            5
# battery        2
# waste          1
# Name: count, dtype: int64

# %%
power_subset[(power_subset['power']=='plant') & 
             (power_subset['plant:source']=='solar')]['plant:output:electricity'].value_counts()
# Out:
# plant:output:electricity
# yes         42
# 25 MW        2
# 100 MW       2
# 22 MW        2
# 50 MW        2
# 5 MW         2
# 20.69 MW     1
# 150 MW       1
# 6.9 MW       1
# 45 MW        1
# 20 MW        1
# 8.6 MW       1
# 132.5 MW     1
# 18 MW        1
# 23 MW        1
# 120 MW       1
# 15 MW        1
# 60 MW        1
# 28.6 MW      1
# 12.6 MW      1
# 7.48 MW      1
# 7.5 MW       1
# 30.4 MW      1
# 75 MW        1
# 154 MW       1
# 128 MW       1
# 159 MW       1
# 27 MW        1
# Name: count, dtype: int64

# %%
power_subset[power_subset['power'] == 'generator']['generator:source'].value_counts()
# Out:
# generator:source
# solar                  20763
# wind                     223
# coal                      59
# oil                       50
# diesel                    44
# hydro                     30
# gas                       16
# geothermal                13
# biomass                    5
# generator                  5
# biofuel                    2
# gasoline                   2
# electricity                2
# electricity_network        1
# nuclear                    1
# Name: count, dtype: int64

# %%
power_subset[(power_subset['power'] == 'generator') 
             & (power_subset['generator:source'] == 'solar')]['location'].value_counts()
# Out:
# location
# surface    16078
# roof         615
# pole           4
# Name: count, dtype: int64

# %%
power_subset[(power_subset['power'] == 'generator') 
             & (power_subset['generator:source'] == 'solar')]
# Out:
#        index element          id generator:method generator:source  \
# 35        35    node  1744951663     photovoltaic            solar
# 55        55    node  2453632160     photovoltaic            solar
# 71        71    node  2674178575             None            solar
# 72        72    node  2674178579             None            solar
# 106      106    node  3268411673             None            solar
# ...      ...     ...         ...              ...              ...
# 27779  27779     way  1383906323     photovoltaic            solar
# 27780  27780     way  1383906324     photovoltaic            solar
# 27781  27781     way  1383906325     photovoltaic            solar
# 27782  27782     way  1383906326     photovoltaic            solar
# 27783  27783     way  1383906327     photovoltaic            solar
#
#       operator:type      power building         name            operator  ...  \
# 35       government  generator     None         None  City of Dasmariñas  ...
# 55       government  generator     None         None  City of Dasmariñas  ...
# 71             None  generator     None  Solar Panel                None  ...
# 72             None  generator     None  Solar Panel                None  ...
# 106            None  generator     None         None                None  ...
# ...             ...        ...      ...          ...                 ...  ...
# 27779          None  generator     None         None                None  ...
# 27780          None  generator     None         None                None  ...
# 27781          None  generator     None         None                None  ...
# 27782          None  generator     None         None                None  ...
# 27783          None  generator     None         None                None  ...
#
#       fenced source_ref plant:output:heat plant:output:steam is_in  \
# 35      None       None              None               None  None
# 55      None       None              None               None  None
# 71      None       None              None               None  None
# 72      None       None              None               None  None
# 106     None       None              None               None  None
# ...      ...        ...               ...                ...   ...
# 27779   None       None              None               None  None
# 27780   None       None              None               None  None
# 27781   None       None              None               None  None
# 27782   None       None              None               None  None
# 27783   None       None              None               None  None
#
#       operator:1995-2010 operator:2010-2020 building:levels:underground  \
# 35                  None               None                        None
# 55                  None               None                        None
# 71                  None               None                        None
# 72                  None               None                        None
# 106                 None               None                        None
# ...                  ...                ...                         ...
# 27779               None               None                        None
# 27780               None               None                        None
# 27781               None               None                        None
# 27782               None               None                        None
# 27783               None               None                        None
#
#       is_in:province                                           geometry
# 35              None                         POINT (120.95685 14.29857)
# 55              None                         POINT (120.95682 14.29873)
# 71              None                         POINT (120.41623 12.65865)
# 72              None                         POINT (120.41653 12.65897)
# 106             None                         POINT (119.78546 16.30702)
# ...              ...                                                ...
# 27779           None  POLYGON ((120.6455 16.08082, 120.64565 16.0808...
# 27780           None  POLYGON ((120.64519 16.08043, 120.6458 16.0804...
# 27781           None  POLYGON ((120.64504 16.08033, 120.6458 16.0803...
# 27782           None  POLYGON ((120.64615 16.07814, 120.6463 16.0781...
# 27783           None  POLYGON ((120.64615 16.07805, 120.6463 16.0780...
#
# [20763 rows x 200 columns]

# %%
# Filter to remove rooftop panels
solar_sites = power_subset[
    (power_subset['power'] == 'generator') &
    (power_subset['generator:source'] == 'solar') &
    ~(  # Negate the rooftop condition
        (power_subset['location'] == 'roof') |
        (power_subset['generator:place'] == 'roof')
    )
]
solar_sites = solar_sites.reset_index()
solar_sites
# Out:
#        level_0  index element          id generator:method generator:source  \
# 0           35     35    node  1744951663     photovoltaic            solar
# 1           55     55    node  2453632160     photovoltaic            solar
# 2           71     71    node  2674178575             None            solar
# 3           72     72    node  2674178579             None            solar
# 4          106    106    node  3268411673             None            solar
# ...        ...    ...     ...         ...              ...              ...
# 20138    27779  27779     way  1383906323     photovoltaic            solar
# 20139    27780  27780     way  1383906324     photovoltaic            solar
# 20140    27781  27781     way  1383906325     photovoltaic            solar
# 20141    27782  27782     way  1383906326     photovoltaic            solar
# 20142    27783  27783     way  1383906327     photovoltaic            solar
#
#       operator:type      power building         name  ... fenced source_ref  \
# 0        government  generator     None         None  ...   None       None
# 1        government  generator     None         None  ...   None       None
# 2              None  generator     None  Solar Panel  ...   None       None
# 3              None  generator     None  Solar Panel  ...   None       None
# 4              None  generator     None         None  ...   None       None
# ...             ...        ...      ...          ...  ...    ...        ...
# 20138          None  generator     None         None  ...   None       None
# 20139          None  generator     None         None  ...   None       None
# 20140          None  generator     None         None  ...   None       None
# 20141          None  generator     None         None  ...   None       None
# 20142          None  generator     None         None  ...   None       None
#
#       plant:output:heat plant:output:steam is_in operator:1995-2010  \
# 0                  None               None  None               None
# 1                  None               None  None               None
# 2                  None               None  None               None
# 3                  None               None  None               None
# 4                  None               None  None               None
# ...                 ...                ...   ...                ...
# 20138              None               None  None               None
# 20139              None               None  None               None
# 20140              None               None  None               None
# 20141              None               None  None               None
# 20142              None               None  None               None
#
#       operator:2010-2020 building:levels:underground is_in:province  \
# 0                   None                        None           None
# 1                   None                        None           None
# 2                   None                        None           None
# 3                   None                        None           None
# 4                   None                        None           None
# ...                  ...                         ...            ...
# 20138               None                        None           None
# 20139               None                        None           None
# 20140               None                        None           None
# 20141               None                        None           None
# 20142               None                        None           None
#
#                                                 geometry
# 0                             POINT (120.95685 14.29857)
# 1                             POINT (120.95682 14.29873)
# 2                             POINT (120.41623 12.65865)
# 3                             POINT (120.41653 12.65897)
# 4                             POINT (119.78546 16.30702)
# ...                                                  ...
# 20138  POLYGON ((120.6455 16.08082, 120.64565 16.0808...
# 20139  POLYGON ((120.64519 16.08043, 120.6458 16.0804...
# 20140  POLYGON ((120.64504 16.08033, 120.6458 16.0803...
# 20141  POLYGON ((120.64615 16.07814, 120.6463 16.0781...
# 20142  POLYGON ((120.64615 16.07805, 120.6463 16.0780...
#
# [20143 rows x 201 columns]

# %%
solar_sites['lamp_type'].value_counts()
# Out:
# lamp_type
# solar_lamp    36
# Name: count, dtype: int64

# %%
# Exclude 'solar_lamp' while keeping rows where lamp_type is NaN or something else
solar_sites_filtered = solar_sites[~(solar_sites['lamp_type'] == 'solar_lamp')]

# %%
solar_sites_filtered['generator:output:electricity'].value_counts()
# Out:
# generator:output:electricity
# yes                   19878
# 25 MW                    15
# small_installation        9
# 20 MW                     3
# 28 MW                     2
# 1.2 MW                    1
# 48.1 MW                   1
# 4 MW                      1
# 212 MW                    1
# Name: count, dtype: int64

# %%
import pandas as pd

# Exclude rows with large MW capacity
def is_too_large(capacity):
    if pd.isnull(capacity):
        return False
    if isinstance(capacity, str):
        if 'MW' in capacity:
            try:
                value = float(capacity.split()[0])
                return value >= 1.0
            except:
                return True  # If not parseable, exclude
    return False

solar_sites_filtered = solar_sites_filtered[~solar_sites_filtered['generator:output:electricity'].apply(is_too_large)]
solar_sites_filtered['generator:output:electricity'].value_counts()
# Out:
# generator:output:electricity
# yes                   19878
# small_installation        9
# Name: count, dtype: int64

# %%
solar_sites_filtered.to_file("../00_data/solar_sites.geojson", driver="GeoJSON")

# %%
# Create a copy to avoid modifying original
gdf = solar_sites_filtered.copy()

# Get a representative point inside each polygon
gdf['representative_point'] = gdf.geometry.representative_point()

# Extract latitude and longitude from the representative points
gdf['latitude'] = gdf['representative_point'].y
gdf['longitude'] = gdf['representative_point'].x

# Select only id, latitude, and longitude
csv_df = gdf[['id', 'latitude', 'longitude']].reset_index(drop=True)
csv_df
# Out:
#                id   latitude   longitude
# 0      2674178575  12.658645  120.416232
# 1      2674178579  12.658966  120.416531
# 2      3268411673  16.307015  119.785458
# 3      6380661297  14.961935  120.906647
# 4      6761083556   7.070329  125.622841
# ...           ...        ...         ...
# 20078  1383906323  16.080773  120.645572
# 20079  1383906324  16.080380  120.645493
# 20080  1383906325  16.080287  120.645420
# 20081  1383906326  16.078098  120.646228
# 20082  1383906327  16.078002  120.646226
#
# [20083 rows x 3 columns]

# %%
# Save to CSV
csv_df.to_csv('../00_data/solar_sites_coords.csv', index=False)

# %% [markdown]
# # Roads

# %%
# tags = {'highway': True}  # fetch all roads
# roads = ox.features_from_place("Philippines", tags)

# %%
# # Get roads
# major_roads = ox.graph_from_place(place, network_type='drive')
# major_roads = ox.graph_to_gdfs(major_roads, nodes=False)  # Convert to GeoDataFrame

# # Query to get all roads (including footpaths, cycleways, and more)
# network = ox.graph_from_place(place, network_type='all')

# # Convert to GeoDataFrame for further manipulation
# network_gdf = ox.graph_to_gdfs(network, nodes=False)

# # Filter out private and restricted roads (using the "access" tag)
# # You can also filter using other tags like "noaccess", "private", or "restricted"
# accessible_roads = network_gdf[~network_gdf['access'].isin(['private', 'restricted'])]

# %%
gdf_roads = gpd.read_file("../00_data/roads_ph.geojson")
gdf_roads
# Out:
#                                 name name:en       highway  surface  \
# 0                               None    None          path     None
# 1                               None    None         track     None
# 2                               None    None         track     None
# 3                               None    None  unclassified     None
# 4                               None    None  unclassified     None
# ...                              ...     ...           ...      ...
# 1438764                         None    None   residential     None
# 1438765                         None    None       service     None
# 1438766                         None    None          path  unpaved
# 1438767  Clark International Raceway    None       raceway     None
# 1438768                         None    None       service     None
#
#         smoothness width lanes oneway bridge layer source name:fil  \
# 0             None  None  None   None   None  None   None     None
# 1             None  None  None   None   None  None   None     None
# 2             None  None  None   None   None  None   None     None
# 3             None  None  None   None   None  None   None     None
# 4             None  None  None   None   None  None   None     None
# ...            ...   ...   ...    ...    ...   ...    ...      ...
# 1438764       None  None  None   None   None  None   None     None
# 1438765       None  None  None   None   None  None   None     None
# 1438766       None  None  None   None   None  None   None     None
# 1438767       None  None  None   None   None  None   None     None
# 1438768       None  None  None   None   None  None   None     None
#
#              osm_id   osm_type  \
# 0         909941797  ways_line
# 1         909943223  ways_line
# 2         909943228  ways_line
# 3         909943234  ways_line
# 4         245905040  ways_line
# ...             ...        ...
# 1438764  1382704079  ways_line
# 1438765  1382704084  ways_line
# 1438766   865980664  ways_line
# 1438767     1501196  relations
# 1438768    15552277  relations
#
#                                                   geometry
# 0        LINESTRING (123.77366 10.37984, 123.77382 10.3...
# 1        LINESTRING (125.83187 7.41616, 125.83189 7.416...
# 2        LINESTRING (125.83353 7.41979, 125.834 7.41936...
# 3         LINESTRING (125.83526 7.4181, 125.83537 7.41825)
# 4        LINESTRING (123.4634 12.30423, 123.46353 12.30...
# ...                                                    ...
# 1438764  LINESTRING (123.71362 10.55836, 123.71374 10.5...
# 1438765  LINESTRING (123.71207 10.56026, 123.71224 10.5...
# 1438766  LINESTRING (125.38903 7.10035, 125.38906 7.09806)
# 1438767  MULTILINESTRING ((120.53532 15.20603, 120.5361...
# 1438768  MULTILINESTRING ((121.06069 14.52991, 121.0607...
#
# [1438769 rows x 15 columns]

# %%
gdf_roads.highway.unique()
# Out:
# array(['path', 'track', 'unclassified', 'residential', 'service',
#        'tertiary', 'primary', 'living_street', 'footway', 'steps',
#        'secondary', 'trunk', 'construction', 'busway', 'pedestrian',
#        'trunk_link', 'primary_link', 'proposed', 'cycleway',
#        'motorway_link', 'secondary_link', 'motorway', 'corridor',
#        'bridleway', 'tertiary_link', 'emergency_bay', 'raceway',
#        'bus_stop', 'platform', 'road', 'abandoned', 'escape', 'crossing',
#        'disused', 'planned', 'closed'], dtype=object)

# %%
# gdf_primary_roads = gdf_roads[gdf_roads['highway'].isin(['primary', 'secondary', 'tertiary'])]

included_values = [
    'motorway', 'trunk', 'primary', 'secondary', 'tertiary',
    'unclassified', 'residential', 'road', 'service',
    'motorway_link', 'trunk_link', 'primary_link',
    'secondary_link', 'tertiary_link'
]

gdf_passable_roads = gdf_roads[gdf_roads['highway'].isin(included_values)]

# %%
primary = ['primary', 'secondary', 'tertiary']
gdf_primary_roads = gdf_roads[gdf_roads['highway'].isin(primary)]
gdf_primary_roads = gdf_primary_roads.reset_index(drop=True)
gdf_primary_roads
# Out:
#                           name name:en    highway  surface smoothness width  \
# 0                         None    None   tertiary     None       None  None
# 1                         None    None   tertiary     None       None  None
# 2                         None    None   tertiary     None       None  None
# 3      Liloan-San Ricardo Road    None    primary     None       None  None
# 4                         None    None   tertiary     None       None  None
# ...                        ...     ...        ...      ...        ...   ...
# 99700      Buhay na Tubig Road    None  secondary     None       None  None
# 99701      Buhay na Tubig Road    None  secondary  asphalt       None  None
# 99702      Buhay na Tubig Road    None  secondary  asphalt       None  None
# 99703      Buhay na Tubig Road    None  secondary  asphalt       None  None
# 99704                     None    None   tertiary     None       None  None
#
#       lanes oneway bridge layer source name:fil      osm_id   osm_type  \
# 0      None   None   None  None   None     None   769534690  ways_line
# 1      None   None   None  None   None     None   245353381  ways_line
# 2      None   None   None  None   None     None   245363415  ways_line
# 3      None     no   None  None   None     None   248622438  ways_line
# 4      None   None   None  None   None     None   909962327  ways_line
# ...     ...    ...    ...   ...    ...      ...         ...        ...
# 99700     2    yes   None  None   None     None  1382676880  ways_line
# 99701     2    yes   None  None   None     None  1382676881  ways_line
# 99702     4   None   None  None   None     None  1382676882  ways_line
# 99703     2    yes   None  None   None     None  1382676883  ways_line
# 99704  None   None    yes     1   Bing     None  1382685940  ways_line
#
#                                                 geometry
# 0      LINESTRING (123.20166 13.41634, 123.20166 13.4...
# 1      LINESTRING (124.79154 10.14581, 124.79183 10.1...
# 2      LINESTRING (124.77645 10.17098, 124.77647 10.1...
# 3      LINESTRING (125.19756 10.0248, 125.19769 10.02...
# 4      LINESTRING (124.79321 10.17785, 124.79294 10.1...
# ...                                                  ...
# 99700  LINESTRING (120.95741 14.40622, 120.95739 14.4...
# 99701  LINESTRING (120.95739 14.40627, 120.95694 14.4...
# 99702  LINESTRING (120.95741 14.40622, 120.95756 14.4...
# 99703  LINESTRING (120.95687 14.40681, 120.9569 14.40...
# 99704  LINESTRING (123.71766 10.56706, 123.71769 10.5...
#
# [99705 rows x 15 columns]

# %%
file_path = "../01_processed_data/philippines_roads.geojson"

gdf_passable_roads = gdf_passable_roads.to_crs(epsg=32651)

# Save only the geometry to a GeoJSON file
gdf_passable_roads[['osm_id','highway','geometry']].to_file(file_path, driver="GeoJSON")

# %%
file_path = "../01_processed_data/philippines_main_roads.geojson"

gdf_primary_roads = gdf_primary_roads.to_crs(epsg=32651)

# Save only the geometry to a GeoJSON file
gdf_primary_roads[['osm_id','geometry']].to_file(file_path, driver="GeoJSON")

# %%
gdf_primary_roads

# Divide into 2 geojson file
gdf_primary_roads_1 = gdf_primary_roads.iloc[:len(gdf_primary_roads)//2]
gdf_primary_roads_2 = gdf_primary_roads.iloc[len(gdf_primary_roads)//2:]

file_path = "../01_processed_data/philippines_main_roads_1.geojson"
gdf_primary_roads_1.to_file(file_path, driver="GeoJSON")

file_path = "../01_processed_data/philippines_main_roads_2.geojson"
gdf_primary_roads_2.to_file(file_path, driver="GeoJSON")

# %% [markdown]
# # Airports

# %%
gdf_airports = gpd.read_file("../00_data/airports_ph.geojson")
gdf_airports
# Out:
#                                             name name:en    aeroway building  \
# 0                                     JCA Hangar    None     hangar      yes
# 1     General Santos International Airport Apron    None      apron     None
# 2                                           None    None      apron     None
# 3                                           None    None    taxiway     None
# 4                                           None    None    helipad     None
# ...                                          ...     ...        ...      ...
# 1353                                        None    None    taxiway     None
# 1354                                Runway 10/28    None     runway     None
# 1355                                        None    None      apron     None
# 1356                                        None    None  aerodrome     None
# 1357          Boracay Aiport Departures Terminal    None   terminal      yes
#
#      emergency emergency:helipad operator:type capacity:persons addr:full  \
# 0         None              None          None             None      None
# 1         None              None          None             None      None
# 2         None              None          None             None      None
# 3         None              None          None             None      None
# 4         None              None          None             None      None
# ...        ...               ...           ...              ...       ...
# 1353      None              None          None             None      None
# 1354      None              None          None             None      None
# 1355      None              None          None             None      None
# 1356      None              None          None             None      None
# 1357      None              None          None             None      None
#
#            addr:city source name:fil      osm_id   osm_type  \
# 0               None   None     None   306516338  ways_poly
# 1     General Santos   None     None   151460881  ways_poly
# 2               None   None     None   312906672  ways_poly
# 3               None   None     None   310027661  ways_poly
# 4               None   None     None  1026238215  ways_poly
# ...              ...    ...      ...         ...        ...
# 1353            None   None     None    18769161  relations
# 1354            None   None     None    18769160  relations
# 1355            None   None     None    18769162  relations
# 1356            None   None     None    18064839  relations
# 1357            None   None     None    18441014  relations
#
#                                                geometry
# 0     POLYGON ((118.75781 9.74038, 118.75781 9.74015...
# 1     POLYGON ((125.09855 6.05853, 125.09858 6.05833...
# 2     POLYGON ((120.54815 15.17384, 120.54895 15.173...
# 3     POLYGON ((122.07062 6.92189, 122.0714 6.92184,...
# 4     POLYGON ((121.94713 21.11778, 121.94713 21.117...
# ...                                                 ...
# 1353  MULTIPOLYGON (((121.03924 12.36325, 121.03924 ...
# 1354  POLYGON ((121.03834 12.36349, 121.03924 12.363...
# 1355  POLYGON ((121.04448 12.3606, 121.04608 12.3601...
# 1356  POLYGON ((122.25931 16.51921, 122.25934 16.518...
# 1357  MULTIPOLYGON (((121.95169 11.92457, 121.95177 ...
#
# [1358 rows x 15 columns]

# %%
file_path = "../01_processed_data/philippines_airports.geojson"

gdf_airports = gdf_airports.to_crs(epsg=32651)

# Save only the geometry to a GeoJSON file
gdf_airports[['osm_id','geometry']].to_file(file_path, driver="GeoJSON")
