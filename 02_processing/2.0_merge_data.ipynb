# %%
import dask_geopandas as dgpd

# Use dask to read Parquet files in parallel
gdf_municipality = dgpd.read_parquet("data/NEW_municipalities.parquet").compute()
# gdf_protected = dgpd.read_parquet("data/protected_areas.parquet").compute()
# gdf_landcover = dgpd.read_parquet("data/land_cover.parquet").compute()
gdf_flood_5 = dgpd.read_parquet("data/flood_risk/FloodRisk_5yr.parquet").compute()
gdf_flood_25 = dgpd.read_parquet("data/flood_risk/FloodRisk_25yr.parquet").compute()
gdf_flood_100 = dgpd.read_parquet("data/flood_risk/FloodRisk_100yr.parquet").compute()

# %%
target_crs = "EPSG:32651"

# Convert GeoPandas to Dask GeoDataFrame
# ddf_landcover = dgpd.from_geopandas(gdf_landcover, npartitions=8)
# ddf_municipality = dgpd.from_geopandas(gdf_municipality, npartitions=8)
# ddf_protected = dgpd.from_geopandas(gdf_protected, npartitions=8)
ddf_flood_5 = dgpd.from_geopandas(gdf_flood_5, npartitions=8)
ddf_flood_25 = dgpd.from_geopandas(gdf_flood_25, npartitions=8)
ddf_flood_100 = dgpd.from_geopandas(gdf_flood_100, npartitions=8)

# Perform parallel CRS conversion
# ddf_landcover = ddf_landcover.to_crs(target_crs)
# ddf_municipality = ddf_municipality.to_crs(target_crs)
# ddf_protected = ddf_protected.to_crs(target_crs)
ddf_flood_5 = ddf_flood_5.to_crs(target_crs)
ddf_flood_25 = ddf_flood_25.to_crs(target_crs)
ddf_flood_100 = ddf_flood_100.to_crs(target_crs)

# Convert back to GeoPandas
# gdf_landcover = ddf_landcover.compute()
# gdf_municipality = ddf_municipality.compute()
# gdf_protected = ddf_protected.compute()
gdf_flood_5 = ddf_flood_5.compute()
gdf_flood_25 = ddf_flood_25.compute()
gdf_flood_100 = ddf_flood_100.compute()

# %% [markdown]
# ## Compute Land Cover Areas per Municipality

# %%
from joblib import Parallel, delayed
import geopandas as gpd
import pandas as pd
import numpy as np
import os

# Function to perform overlay on a subset of data
def overlay_partition(subset):
    return gpd.overlay(subset, gdf_municipality, how="intersection")

# Split landcover into smaller chunks
num_partitions = min(128, os.cpu_count() // 2)  # Adjust based on system load
gdf_split = np.array_split(gdf_landcover, num_partitions)

# Run overlay in parallel
results = Parallel(n_jobs=num_partitions)(delayed(overlay_partition)(gdf) for gdf in gdf_split)

# Combine results
landcover_joined = gpd.GeoDataFrame(pd.concat(results, ignore_index=True))

# %%
landcover_joined
# Out:
#         class_id     adm3_psgc  Count Region        Province Municipality  \
# 0              2  1.600303e+09      1    MIN  agusan del sur    esperanza
# 1              2  1.600303e+09      1    MIN  agusan del sur    esperanza
# 2              2  1.600303e+09      1    MIN  agusan del sur    esperanza
# 3              2  1.600303e+09      1    MIN  agusan del sur    esperanza
# 4              2  1.600303e+09      1    MIN  agusan del sur    esperanza
# ...          ...           ...    ...    ...             ...          ...
# 627850         2  1.600303e+09      1    MIN  agusan del sur    esperanza
# 627851         2  1.600303e+09      1    MIN  agusan del sur    esperanza
# 627852         2  1.600303e+09      1    MIN  agusan del sur    esperanza
# 627853         2  1.600303e+09      1    MIN  agusan del sur    esperanza
# 627854         2  1.600303e+09      1    MIN  agusan del sur    esperanza
#
#            adm1_psgc     adm2_psgc geo_level   len_crs      area_crs  len_km  \
# 0       1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# 1       1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# 2       1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# 3       1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# 4       1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# ...              ...           ...       ...       ...           ...     ...
# 627850  1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# 627851  1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# 627852  1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# 627853  1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
# 627854  1.600000e+09  1.600300e+09       Mun  207067.0  1.331903e+09   207.0
#
#         area_km2                                           geometry
# 0         1331.0  POLYGON ((765559.913 954794.654, 765559.088 95...
# 1         1331.0  POLYGON ((804058.776 954799.665, 804059.998 95...
# 2         1331.0  POLYGON ((773414.998 954809.353, 773408.82 954...
# 3         1331.0  POLYGON ((786359.216 954762.345, 786356.05 954...
# 4         1331.0  POLYGON ((793679.752 954831.008, 793679.733 95...
# ...          ...                                                ...
# 627850    1331.0  POLYGON ((767548.065 954611.71, 767550.875 954...
# 627851    1331.0  POLYGON ((791768.182 954750.004, 791764.37 954...
# 627852    1331.0  POLYGON ((766692.937 954657.614, 766689.58 954...
# 627853    1331.0  POLYGON ((805065.756 954618.501, 805064.426 95...
# 627854    1331.0  POLYGON ((774829.365 954489.782, 774828.525 95...
#
# [627855 rows x 14 columns]

# %%
import dask_geopandas as dask_gpd
import geopandas as gpd

# Convert GeoDataFrames to Dask format for parallel processing
ddf_landcover = dask_gpd.from_geopandas(landcover_joined, npartitions=16)  # Adjust partitions based on CPU cores
ddf_municipality = dask_gpd.from_geopandas(gdf_municipality, npartitions=16)

# Compute area in parallel
ddf_landcover["landcover_area"] = ddf_landcover.geometry.area
ddf_municipality["municipality_area"] = ddf_municipality.geometry.area

# Convert back to GeoPandas
landcover_joined = ddf_landcover.compute()
gdf_municipality = ddf_municipality.compute()

# Total area per municipality
municipality_area = gdf_municipality.set_index("adm3_psgc")["municipality_area"]

# Aggregate by municipality and land cover type
landcover_stats = (
    landcover_joined.groupby(["adm3_psgc", "class_id"])["landcover_area"]
    .sum()
    .unstack(fill_value=0)
    .div(municipality_area, axis=0)  # Normalize
).reset_index()

# %%
landcover_stats = landcover_stats.rename(
    columns={
        "adm3_psgc": "municipality_id",
        1: "% Forest",
        2: "% Crops",
        3: "% Flatlands",
        4: "% Built-up",
        5: "% Wetlands",
    }
)

landcover_stats
# Out:
# class_id  municipality_id  % Forest   % Crops  % Flatlands  % Built-up  \
# 0            1.028030e+08  0.046231  0.421475     0.443372    0.059711
# 1            1.028120e+08  0.000401  0.485153     0.316229    0.147883
# 2            1.028150e+08  0.503109  0.137716     0.318179    0.030086
# 3            1.028160e+08  0.001565  0.497563     0.376649    0.074523
# 4            1.028230e+08  0.190629  0.094527     0.693880    0.008286
# ..                    ...       ...       ...          ...         ...
# 737          1.908816e+09  0.000000  0.220524     0.001030    0.011617
# 738          1.908818e+09  0.000000  0.798091     0.015941    0.047773
# 739          1.908820e+09  0.000000  0.854234     0.006270    0.116677
# 740          1.908821e+09  0.000000  0.750004     0.113976    0.035925
# 741          1.908822e+09  0.037971  0.692691     0.244250    0.017458
#
# class_id  % Wetlands
# 0           0.028706
# 1           0.049561
# 2           0.009873
# 3           0.049620
# 4           0.012678
# ..               ...
# 737         0.766829
# 738         0.138195
# 739         0.022819
# 740         0.100095
# 741         0.007631
#
# [742 rows x 6 columns]

# %% [markdown]
# ## Compute % Protected Area per Municipality

# %%
from joblib import Parallel, delayed
import geopandas as gpd
import pandas as pd
import numpy as np
import os

# Function to perform overlay on a subset of data
def overlay_partition(subset):
    return gpd.overlay(subset, gdf_municipality, how="intersection")

# Split landcover into smaller chunks
num_partitions = min(128, os.cpu_count() // 2)  # Adjust based on system load
gdf_split = np.array_split(gdf_protected, num_partitions)

# Run overlay in parallel
results = Parallel(n_jobs=num_partitions)(delayed(overlay_partition)(gdf) for gdf in gdf_split)

# Combine results
protected_joined = gpd.GeoDataFrame(pd.concat(results, ignore_index=True))

# %%
# Compute area in parallel
ddf_protected = dask_gpd.from_geopandas(protected_joined, npartitions=16)  # Adjust partitions based on CPU cores
ddf_protected["protected_area"] = ddf_protected.geometry.area
protected_joined = ddf_protected.compute()

municipality_area = gdf_municipality.set_index("adm3_psgc")["municipality_area"]

protected_stats = (
        protected_joined.groupby("adm3_psgc")["protected_area"]
        .sum()
        .div(municipality_area, axis=0)  # Normalize
        .fillna(0)  # Fill NaN values with 0
    ).reset_index()
protected_stats = protected_stats.rename(
    columns={
        "adm3_psgc": "Municipality ID",
        0: "% Protected Area",
    }
)

protected_stats
# Out:
#      Municipality ID  % Protected Area
# 0       1.028030e+08          0.001027
# 1       1.028120e+08          0.000000
# 2       1.028150e+08          0.180760
# 3       1.028160e+08          0.054449
# 4       1.028230e+08          0.005622
# ..               ...               ...
# 737     1.908816e+09          0.000000
# 738     1.908818e+09          0.000000
# 739     1.908820e+09          0.000000
# 740     1.908821e+09          0.000000
# 741     1.908822e+09          0.039427
#
# [742 rows x 2 columns]

# %% [markdown]
# ## Compute Flood Risk per Municipality
#
# We add the Province Codes (adm2_psgc) to the flood risk gdf to reduce the overlay scope.

# %% [markdown]
# ### Preprocess Data

# %%
gdf_municipality
# Out:
#         adm3_psgc  Count Region             Province  \
# 0    1.028030e+08      1    NLZ         ilocos norte
# 1    1.028120e+08      1    NLZ         ilocos norte
# 2    1.028150e+08      2    NLZ         ilocos norte
# 3    1.028160e+08      1    NLZ         ilocos norte
# 4    1.028230e+08      2    NLZ         ilocos norte
# ..            ...    ...    ...                  ...
# 737  1.908816e+09      2    MIN  maguindanao del sur
# 738  1.908818e+09      1    MIN  maguindanao del sur
# 739  1.908820e+09      1    MIN  maguindanao del sur
# 740  1.908821e+09      2    VIS  maguindanao del sur
# 741  1.908822e+09      2    MIN  maguindanao del sur
#
#                  Municipality     adm1_psgc     adm2_psgc geo_level   len_crs  \
# 0                       badoc  1.000000e+08  1.028000e+08       Mun   64985.0
# 1               city of laoag  1.000000e+08  1.028000e+08      City   53964.0
# 2                    pagudpud  1.000000e+08  1.028000e+08       Mun   85639.0
# 3                       paoay  1.000000e+08  1.028000e+08       Mun   43881.0
# 4                      vintar  1.000000e+08  1.028000e+08       Mun  105732.0
# ..                        ...           ...           ...       ...       ...
# 737                pagalungan  1.900000e+09  1.908800e+09       Mun  127787.0
# 738                    pandag  1.900000e+09  1.908800e+09       Mun   40384.0
# 739             shariff aguak  1.900000e+09  1.908800e+09       Mun   43863.0
# 740  shariff saydona mustapha  1.900000e+09  1.908800e+09       Mun   78042.0
# 741                 south upi  1.900000e+09  1.908800e+09       Mun  104398.0
#
#         area_crs  len_km  area_km2  \
# 0     80758428.0    64.0      80.0
# 1    110146974.0    53.0     110.0
# 2    193261277.0    85.0     193.0
# 3     69564806.0    43.0      69.0
# 4    531249117.0   105.0     531.0
# ..           ...     ...       ...
# 737  198328294.0   127.0     198.0
# 738   44662780.0    40.0      44.0
# 739   36575547.0    43.0      36.0
# 740   55909439.0    78.0      55.0
# 741  440961926.0   104.0     440.0
#
#                                               geometry
# 0    POLYGON ((232924.209 1989474.502, 232926.91 19...
# 1    POLYGON ((248393.247 2016552.78, 248424.831 20...
# 2    POLYGON ((285928.399 2055561.259, 285954.238 2...
# 3    POLYGON ((241783.156 2006726.213, 241835.225 2...
# 4    POLYGON ((275061.25 2039069.568, 279694.026 20...
# ..                                                 ...
# 737  MULTIPOLYGON (((689655.039 789220.539, 689656....
# 738  POLYGON ((706127.27 744160.271, 705163.117 743...
# 739  POLYGON ((664236.134 759402.116, 664165.452 75...
# 740  POLYGON ((671841.811 776638.023, 671920.415 77...
# 741  POLYGON ((631983.188 766590.211, 636927.804 76...
#
# [742 rows x 13 columns]

# %%
# Check for unique province count in gdf_municipality
print(gdf_municipality["Province"].nunique())
print(gdf_municipality["Province"].isna().sum())
print(gdf_municipality["adm2_psgc"].nunique())

# Display rows with missing province values
missing_province = gdf_municipality[gdf_municipality["Province"].isna()]
missing_province # HUCs
# Out:
# 82
# 22
# 104
#         adm3_psgc  Count Region Province             Municipality  \
# 153  3.301000e+08     12    NLZ     None          city of angeles
# 154  3.314000e+08      5    NLZ     None         city of olongapo
# 220  4.312000e+08      5    SLZ     None           city of lucena
# 320  6.302000e+08      9    VIS     None          city of bacolod
# 321  6.310000e+08      8    VIS     None           city of iloilo
# 402  7.306000e+08     19    VIS     None             city of cebu
# 403  7.311000e+08     12    VIS     None        city of lapu-lapu
# 404  7.313000e+08      5    VIS     None          city of mandaue
# 469  8.316000e+08     15    VIS     None         city of tacloban
# 490  9.317000e+08     61    MIN     None        city of zamboanga
# 525  1.030500e+09     20    MIN     None   city of cagayan de oro
# 526  1.030900e+09     15    MIN     None           city of iligan
# 550  1.130700e+09     36    MIN     None            city of davao
# 580  1.230800e+09     12    MIN     None   city of general santos
# 581  1.380100e+09      2    NCR     None         city of caloocan
# 582  1.380300e+09      2    NCR     None           city of makati
# 583  1.380800e+09      2    NCR     None       city of muntinlupa
# 584  1.381200e+09      2    NCR     None            city of pasig
# 585  1.381500e+09      2    NCR     None           city of taguig
# 606  1.430300e+09      2    NLZ     None           city of baguio
# 653  1.630400e+09     17    MIN     None           city of butuan
# 697  1.731500e+09     26    SLZ     None  city of puerto princesa
#
#         adm1_psgc     adm2_psgc geo_level   len_crs      area_crs  len_km  \
# 153  3.000000e+08  3.301000e+08      City   66451.0  1.211398e+08    66.0
# 154  3.000000e+08  3.314000e+08      City  107151.0  1.412713e+08   107.0
# 220  4.000000e+08  4.312000e+08      City   60969.0  8.357117e+07    60.0
# 320  6.000000e+08  6.302000e+08      City   93735.0  1.622480e+08    93.0
# 321  6.000000e+08  6.310000e+08      City   57927.0  7.263026e+07    57.0
# 402  7.000000e+08  7.306000e+08      City   88577.0  2.907363e+08    88.0
# 403  7.000000e+08  7.311000e+08      City  164331.0  6.729994e+07   164.0
# 404  7.000000e+08  7.313000e+08      City   37143.0  3.110909e+07    37.0
# 469  8.000000e+08  8.316000e+08      City  101639.0  1.060181e+08   101.0
# 490  9.000000e+08  9.317000e+08      City  521492.0  1.496293e+09   521.0
# 525  1.000000e+09  1.030500e+09      City  190031.0  5.066151e+08   190.0
# 526  1.000000e+09  1.030900e+09      City  175044.0  5.320631e+08   175.0
# 550  1.100000e+09  1.130700e+09      City  310518.0  2.343697e+09   310.0
# 580  1.200000e+09  1.230800e+09      City  161410.0  5.214156e+08   161.0
# 581  1.300000e+09  1.380100e+09      City   75603.0  5.324914e+07    75.0
# 582  1.300000e+09  1.380300e+09      City   28411.0  2.497153e+07    28.0
# 583  1.300000e+09  1.380800e+09      City   42886.0  3.918440e+07    42.0
# 584  1.300000e+09  1.381200e+09      City   37687.0  3.131213e+07    37.0
# 585  1.300000e+09  1.381500e+09      City   37363.0  3.553054e+07    37.0
# 606  1.400000e+09  1.430300e+09      City   35159.0  5.813405e+07    35.0
# 653  1.600000e+09  1.630400e+09      City  134573.0  6.499572e+08   134.0
# 697  1.700000e+09  1.731500e+09      City  641735.0  2.178426e+09   641.0
#
#      area_km2                                           geometry
# 153     121.0  POLYGON ((244650.966 1679143.433, 244669.678 1...
# 154     141.0  MULTIPOLYGON (((214421.225 1644596.896, 214393...
# 220      83.0  POLYGON ((352517.579 1546361.061, 353053.521 1...
# 320     162.0  POLYGON ((515237.851 1178348.844, 515154.242 1...
# 321      72.0  POLYGON ((455771.9 1189494.04, 455771.024 1189...
# 402     290.0  MULTIPOLYGON (((597598.39 1159940.648, 597977....
# 403      67.0  MULTIPOLYGON (((606153.03 1134354.281, 606154....
# 404      31.0  POLYGON ((605184.859 1145150.119, 605184.882 1...
# 469     106.0  MULTIPOLYGON (((714752.696 1255793.946, 714750...
# 490    1496.0  MULTIPOLYGON (((395823.254 759783.209, 395838....
# 525     506.0  POLYGON ((693068.571 941380.386, 693089.854 94...
# 526     532.0  POLYGON ((650843.963 919963.629, 651937.552 91...
# 550    2343.0  POLYGON ((780681.669 837078.523, 780659.968 83...
# 580     521.0  POLYGON ((751091.153 690925.334, 751102.251 69...
# 581      53.0  MULTIPOLYGON (((295432.405 1633664.936, 295432...
# 582      24.0  POLYGON ((290060.391 1611437.468, 290071.525 1...
# 583      39.0  POLYGON ((290610.409 1600231.615, 290596.719 1...
# 584      31.0  POLYGON ((295549.628 1617224.763, 295526.746 1...
# 585      35.0  POLYGON ((295625.087 1607412.928, 295678.701 1...
# 606      58.0  POLYGON ((246875.199 1817827.847, 246881.792 1...
# 653     649.0  POLYGON ((800752.113 1001323.022, 797036.997 9...
# 697    2178.0  MULTIPOLYGON (((68856.519 1133084.736, 68856.5...

# %%
gdf_flood_5.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FloodRisk          207 non-null    float64
#  1   geometry           207 non-null    geometry
#  2   Province           207 non-null    string
#  3   FloodReturnPeriod  207 non-null    string
# dtypes: float64(1), geometry(1), string(2)
# memory usage: 9.2 KB

# %% [markdown]
# We need to:
# - Manually determine the codes for the 15 missing values (5 province/s)
#     - compostelavalley = davaodeoro
#     - misamis oriental = misamisoriental
#     - maguindanao: USE region code (now split into del norte and del sur) [1900000000.0]
#     - metromanila: USE NCR region code [1300000000.0]
#     - catanduanes: NO SITE INFO
# - Also add region codes in case the codes don't match (Tacloban City has different code from Leyte)
#
# Expected remaining missing value:
# - adm2_psgc: 9
# - adm1_psgc: 3 (catanduanes only)

# %%
gdf_flood_5['Province'] = gdf_flood_5['Province'].str.lower()

# Create a mapping of 'Province' to 'adm2_psgc' in gdf_municipality
# Get the first 'adm2_psgc' and 'adm1_psgc' for each 'Province' in gdf_municipality
province_to_codes = gdf_municipality.groupby('Province').agg({
    'adm2_psgc': 'first',  
    'adm1_psgc': 'first'   
})

# Remove spaces from the 'Province' values in province_to_code (index)
province_to_codes.index = province_to_codes.index.str.replace(" ", "")

# Manually define any special 'adm1_psgc' codes for specific provinces
manual_adm1_psgc = {
    'metromanila': 1300000000,
    'maguindanao': 1900000000,
}

# Change "misamis oriental to misamisoriental"
gdf_flood_5['Province'] = gdf_flood_5['Province'].str.replace("misamis oriental", "misamisoriental")

# Change "compostelavalley" to "davaodeoro"
gdf_flood_5['Province'] = gdf_flood_5['Province'].str.replace("compostelavalley", "davaodeoro")

# Map the province codes to gdf_flood_5
gdf_flood_5['adm2_psgc'] = gdf_flood_5['Province'].map(province_to_codes['adm2_psgc'])
gdf_flood_5['adm1_psgc'] = gdf_flood_5['Province'].map(province_to_codes['adm1_psgc'])

# Fill in the manually defined values for adm1_psgc (e.g., for 'metromanila')
gdf_flood_5['adm1_psgc'] = gdf_flood_5['adm1_psgc'].fillna(gdf_flood_5['Province'].map(manual_adm1_psgc))

# Display missing province values
print("Number of missing adm2 codes in gdf_flood_5:", gdf_flood_5["adm2_psgc"].isna().sum())
print("Number of missing adm1 codes in gdf_flood_5:", gdf_flood_5["adm1_psgc"].isna().sum())
missing_code = gdf_flood_5[gdf_flood_5["adm2_psgc"].isna() | gdf_flood_5["adm1_psgc"].isna()]
missing_code
# Out:
# Number of missing adm2 codes in gdf_flood_5: 9
# Number of missing adm1 codes in gdf_flood_5: 3
#      FloodRisk                                           geometry  \
# 84         1.0  MULTIPOLYGON (((703425 730065, 703425 730035, ...
# 85         2.0  MULTIPOLYGON (((702715.959 730064.752, 702712....
# 86         3.0  MULTIPOLYGON (((697515 730425, 697515 730395, ...
# 87         1.0  MULTIPOLYGON (((285082.91 1587802.12, 285072.9...
# 88         2.0  MULTIPOLYGON (((285072.91 1587802.12, 285072.9...
# 89         3.0  MULTIPOLYGON (((285062.91 1587802.12, 285062.9...
# 147        1.0  MULTIPOLYGON (((630030 1495910.469, 630000 149...
# 148        2.0  MULTIPOLYGON (((630020 1495920, 630020 1495910...
# 149        3.0  MULTIPOLYGON (((628810 1495970, 628810 1495960...
#
#         Province FloodReturnPeriod  adm2_psgc     adm1_psgc
# 84   maguindanao               5yr        NaN  1.900000e+09
# 85   maguindanao               5yr        NaN  1.900000e+09
# 86   maguindanao               5yr        NaN  1.900000e+09
# 87   metromanila               5yr        NaN  1.300000e+09
# 88   metromanila               5yr        NaN  1.300000e+09
# 89   metromanila               5yr        NaN  1.300000e+09
# 147  catanduanes               5yr        NaN           NaN
# 148  catanduanes               5yr        NaN           NaN
# 149  catanduanes               5yr        NaN           NaN

# %%
gdf_flood_25['Province'] = gdf_flood_25['Province'].str.lower()

# Create a mapping of 'Province' to 'adm2_psgc' in gdf_municipality
# Get the first 'adm2_psgc' and 'adm1_psgc' for each 'Province' in gdf_municipality
province_to_codes = gdf_municipality.groupby('Province').agg({
    'adm2_psgc': 'first',  
    'adm1_psgc': 'first'   
})

# Remove spaces from the 'Province' values in province_to_code (index)
province_to_codes.index = province_to_codes.index.str.replace(" ", "")

# Manually define any special 'adm1_psgc' codes for specific provinces
manual_adm1_psgc = {
    'metromanila': 1300000000,
    'maguindanao': 1900000000,
}

# Change "misamis oriental to misamisoriental"
gdf_flood_25['Province'] = gdf_flood_25['Province'].str.replace("misamis oriental", "misamisoriental")

# Change "compostelavalley" to "davaodeoro"
gdf_flood_25['Province'] = gdf_flood_25['Province'].str.replace("compostelavalley", "davaodeoro")

# Map the province codes to gdf_flood_25
gdf_flood_25['adm2_psgc'] = gdf_flood_25['Province'].map(province_to_codes['adm2_psgc'])
gdf_flood_25['adm1_psgc'] = gdf_flood_25['Province'].map(province_to_codes['adm1_psgc'])

# Fill in the manually defined values for adm1_psgc (e.g., for 'metromanila')
gdf_flood_25['adm1_psgc'] = gdf_flood_25['adm1_psgc'].fillna(gdf_flood_25['Province'].map(manual_adm1_psgc))

# Display missing province values
print("Number of missing adm2 codes in gdf_flood_25:", gdf_flood_25["adm2_psgc"].isna().sum())
print("Number of missing adm1 codes in gdf_flood_25:", gdf_flood_25["adm1_psgc"].isna().sum())
missing_code = gdf_flood_25[gdf_flood_25["adm2_psgc"].isna() | gdf_flood_25["adm1_psgc"].isna()]
missing_code
# Out:
# Number of missing adm2 codes in gdf_flood_25: 9
# Number of missing adm1 codes in gdf_flood_25: 3
#     FloodRisk                                           geometry     Province  \
# 39        1.0  MULTIPOLYGON (((630040 1495911.06, 630000 1495...  catanduanes
# 40        2.0  MULTIPOLYGON (((629080 1495920, 629080 1495910...  catanduanes
# 41        3.0  MULTIPOLYGON (((628810 1495970, 628810 1495960...  catanduanes
# 84        1.0  MULTIPOLYGON (((703425 730035, 703425 730014.3...  maguindanao
# 85        2.0  MULTIPOLYGON (((697455 730280.917, 697455 7302...  maguindanao
# 86        3.0  MULTIPOLYGON (((703425 730125, 703425 730095, ...  maguindanao
# 93        1.0  MULTIPOLYGON (((285132.91 1587822.12, 285132.9...  metromanila
# 94        2.0  MULTIPOLYGON (((285082.91 1587812.12, 285082.9...  metromanila
# 95        3.0  MULTIPOLYGON (((285072.91 1587802.12, 285072.9...  metromanila
#
#    FloodReturnPeriod  adm2_psgc     adm1_psgc
# 39              25yr        NaN           NaN
# 40              25yr        NaN           NaN
# 41              25yr        NaN           NaN
# 84              25yr        NaN  1.900000e+09
# 85              25yr        NaN  1.900000e+09
# 86              25yr        NaN  1.900000e+09
# 93              25yr        NaN  1.300000e+09
# 94              25yr        NaN  1.300000e+09
# 95              25yr        NaN  1.300000e+09

# %%
gdf_flood_100['Province'] = gdf_flood_100['Province'].str.lower()

# Create a mapping of 'Province' to 'adm2_psgc' in gdf_municipality
# Get the first 'adm2_psgc' and 'adm1_psgc' for each 'Province' in gdf_municipality
province_to_codes = gdf_municipality.groupby('Province').agg({
    'adm2_psgc': 'first',  
    'adm1_psgc': 'first'   
})

# Remove spaces from the 'Province' values in province_to_code (index)
province_to_codes.index = province_to_codes.index.str.replace(" ", "")

# Manually define any special 'adm1_psgc' codes for specific provinces
manual_adm1_psgc = {
    'metromanila': 1300000000,
    'maguindanao': 1900000000,
}

# Change "misamis oriental to misamisoriental"
gdf_flood_100['Province'] = gdf_flood_100['Province'].str.replace("misamis oriental", "misamisoriental")

# Change "compostelavalley" to "davaodeoro"
gdf_flood_100['Province'] = gdf_flood_100['Province'].str.replace("compostelavalley", "davaodeoro")

# Map the province codes to gdf_flood_100
gdf_flood_100['adm2_psgc'] = gdf_flood_100['Province'].map(province_to_codes['adm2_psgc'])
gdf_flood_100['adm1_psgc'] = gdf_flood_100['Province'].map(province_to_codes['adm1_psgc'])

# Fill in the manually defined values for adm1_psgc (e.g., for 'metromanila')
gdf_flood_100['adm1_psgc'] = gdf_flood_100['adm1_psgc'].fillna(gdf_flood_100['Province'].map(manual_adm1_psgc))

# Display missing province values
print("Number of missing adm2 codes in gdf_flood_100:", gdf_flood_100["adm2_psgc"].isna().sum())
print("Number of missing adm1 codes in gdf_flood_100:", gdf_flood_100["adm1_psgc"].isna().sum())
missing_code = gdf_flood_100[gdf_flood_100["adm2_psgc"].isna() | gdf_flood_100["adm1_psgc"].isna()]
missing_code
# Out:
# Number of missing adm2 codes in gdf_flood_100: 9
# Number of missing adm1 codes in gdf_flood_100: 3
#     FloodRisk                                           geometry     Province  \
# 36        1.0  MULTIPOLYGON (((630020 1495910, 630020 1495909...  catanduanes
# 37        2.0  MULTIPOLYGON (((630020 1495910, 630022.055 149...  catanduanes
# 38        3.0  MULTIPOLYGON (((627680 1495960, 627680 1495950...  catanduanes
# 63        1.0  MULTIPOLYGON (((702375 730365, 702375 730343.1...  maguindanao
# 64        2.0  MULTIPOLYGON (((703425 730035, 703425 730014.3...  maguindanao
# 65        3.0  MULTIPOLYGON (((703158.072 730162.337, 703155 ...  maguindanao
# 69        1.0  MULTIPOLYGON (((285550 1590130, 285550 1590120...  metromanila
# 70        2.0  MULTIPOLYGON (((285590 1590210, 285590 1590200...  metromanila
# 71        3.0  MULTIPOLYGON (((287455 1590365, 287465 1590365...  metromanila
#
#    FloodReturnPeriod  adm2_psgc     adm1_psgc
# 36             100yr        NaN           NaN
# 37             100yr        NaN           NaN
# 38             100yr        NaN           NaN
# 63             100yr        NaN  1.900000e+09
# 64             100yr        NaN  1.900000e+09
# 65             100yr        NaN  1.900000e+09
# 69             100yr        NaN  1.300000e+09
# 70             100yr        NaN  1.300000e+09
# 71             100yr        NaN  1.300000e+09

# %%
gdf_municipality_reduced = gdf_municipality[["adm3_psgc", "adm2_psgc","adm1_psgc","Municipality","geometry"]]
gdf_municipality_reduced
# Out:
#         adm3_psgc     adm2_psgc     adm1_psgc              Municipality  \
# 0    1.028030e+08  1.028000e+08  1.000000e+08                     badoc
# 1    1.028120e+08  1.028000e+08  1.000000e+08             city of laoag
# 2    1.028150e+08  1.028000e+08  1.000000e+08                  pagudpud
# 3    1.028160e+08  1.028000e+08  1.000000e+08                     paoay
# 4    1.028230e+08  1.028000e+08  1.000000e+08                    vintar
# ..            ...           ...           ...                       ...
# 737  1.908816e+09  1.908800e+09  1.900000e+09                pagalungan
# 738  1.908818e+09  1.908800e+09  1.900000e+09                    pandag
# 739  1.908820e+09  1.908800e+09  1.900000e+09             shariff aguak
# 740  1.908821e+09  1.908800e+09  1.900000e+09  shariff saydona mustapha
# 741  1.908822e+09  1.908800e+09  1.900000e+09                 south upi
#
#                                               geometry
# 0    POLYGON ((232924.209 1989474.502, 232926.91 19...
# 1    POLYGON ((248393.247 2016552.78, 248424.831 20...
# 2    POLYGON ((285928.399 2055561.259, 285954.238 2...
# 3    POLYGON ((241783.156 2006726.213, 241835.225 2...
# 4    POLYGON ((275061.25 2039069.568, 279694.026 20...
# ..                                                 ...
# 737  MULTIPOLYGON (((689655.039 789220.539, 689656....
# 738  POLYGON ((706127.27 744160.271, 705163.117 743...
# 739  POLYGON ((664236.134 759402.116, 664165.452 75...
# 740  POLYGON ((671841.811 776638.023, 671920.415 77...
# 741  POLYGON ((631983.188 766590.211, 636927.804 76...
#
# [742 rows x 5 columns]

# %%
gdf_flood_5_reduced = gdf_flood_5[["adm1_psgc", "adm2_psgc","FloodRisk","geometry"]]
gdf_flood_25_reduced = gdf_flood_25[["adm1_psgc", "adm2_psgc","FloodRisk","geometry"]]
gdf_flood_100_reduced = gdf_flood_100[["adm1_psgc", "adm2_psgc","FloodRisk","geometry"]]

# %%
for gdf in [gdf_municipality, gdf_flood_5_reduced, gdf_flood_25_reduced, gdf_flood_100_reduced]:
    gdf.loc[:, 'adm2_psgc'] = gdf['adm2_psgc'].fillna(-1).astype(int)
    gdf.loc[:, 'adm1_psgc'] = gdf['adm1_psgc'].fillna(-1).astype(int)

# %%
for gdf in [gdf_flood_5_reduced, gdf_flood_25_reduced, gdf_flood_100_reduced]:
    gdf["geometry"] = gdf["geometry"].simplify(tolerance=0.01, preserve_topology=True)
    gdf = gdf.explode(index_parts=False)

# %% [markdown]
# ### Find intersections

# %%
import geopandas as gpd
import pandas as pd

import logging
logging.basicConfig(level=logging.DEBUG)

def get_intersections(gdf_flood, gdf_municipality):
    municipality_processed = 0

    # Group flood data by (adm2_psgc, adm1_psgc) for faster lookup
    print("Grouping flood data by adm2_psgc and adm1_psgc...")
    flood_grouped = gdf_flood.groupby(['adm2_psgc', 'adm1_psgc'])

    intersections = []

    for _, municipality in gdf_municipality.iterrows():
        adm2_psgc = municipality['adm2_psgc']
        adm1_psgc = municipality['adm1_psgc']

        print(f"Processing Municipality: {municipality['Municipality']} (adm2_psgc: {adm2_psgc}, adm1_psgc: {adm1_psgc})")

        # Try to get matching flood data
        filtered_flood = None
        try:
            filtered_flood = flood_grouped.get_group((adm2_psgc, adm1_psgc))
        except KeyError:
            try:
                filtered_flood = flood_grouped.get_group((adm1_psgc,))
            except KeyError:
                print(f"No flood data found for {municipality['Municipality']}")
                continue  # Skip to next municipality

        # Convert single municipality row to GeoDataFrame
        municipality_gdf = gpd.GeoDataFrame([municipality], geometry='geometry', crs=gdf_flood.crs)

        # Perform intersection
        print("Calculating intersection...")
        intersection = gpd.overlay(filtered_flood, municipality_gdf, how='intersection')
        intersections.append(intersection)

        municipality_processed += 1
        print(f"Processed {municipality_processed}/{len(gdf_municipality)} municipalities.")

    # Combine all intersections into one GeoDataFrame
    if intersections:
        result = gpd.GeoDataFrame(pd.concat(intersections, ignore_index=True))
    else:
        result = gpd.GeoDataFrame()  # Return an empty GeoDataFrame if no intersections

    return result


intersections_5 = get_intersections(gdf_flood_5_reduced, gdf_municipality_reduced.iloc[:2])
# Out:
# Grouping flood data by adm2_psgc and adm1_psgc...
# Processing Municipality: badoc (adm2_psgc: 102800000.0, adm1_psgc: 100000000.0)
# Calculating intersection...
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import geopandas as gpd
import dask_geopandas as dgpd
import pandas as pd

import logging
logging.basicConfig(level=logging.DEBUG)


def get_intersections(gdf_flood, gdf_municipality):
    municipality_processed = 0

    # First, group flood data by adm2_psgc and adm1_psgc for efficient filtering
    print("Grouping flood data by adm2_psgc and adm1_psgc...")
    flood_grouped = gdf_flood.groupby(['adm2_psgc', 'adm1_psgc'])

    # Initialize an empty list to store the results of each intersection
    intersections = []

    # Convert the municipality DataFrame to Dask to enable parallel operations
    print("Converting municipality GeoDataFrame to Dask...")
    gdf_municipality = dgpd.from_geopandas(gdf_municipality, npartitions=4)

    def process_municipality(municipality):
        global municipality_processed
        # Get the current municipality's adm2_psgc and adm1_psgc
        adm2_psgc = municipality['adm2_psgc']
        adm1_psgc = municipality['adm1_psgc']

        print(f"Processing Municipality: {municipality['Municipality']} (adm2_psgc: {adm2_psgc}, adm1_psgc: {adm1_psgc})")

        # Try to get matching flood data
        filtered_flood = None
        try:
            filtered_flood = flood_grouped.get_group((adm2_psgc, adm1_psgc))
        except:
            try:
                filtered_flood = flood_grouped.get_group((adm1_psgc,))
            except:
                print(f"No flood data found for {municipality['Municipality']}")
                return None  # Skip to next municipality

        
        # Convert the municipality row to a GeoDataFrame
        print("Converting municipality row to GeoDataFrame...")
        municipality_gdf = gpd.GeoDataFrame([municipality], geometry='geometry', crs=gdf_flood.crs)

        # Perform the intersection
        print("Calculating intersection...")
        intersection = gpd.overlay(filtered_flood, municipality_gdf, how='intersection')

        municipality_processed += 1
        print(f"Processed {municipality_processed} municipalities!")
        return intersection

    # Apply the function to each municipality in parallel
    results = gdf_municipality.map_partitions(lambda df: [process_municipality(row) for _, row in df.iterrows()])

    # Flatten the list of results and remove None values
    intersections = [inter for sublist in results.compute() for inter in sublist if inter is not None]

    # Combine all the intersections into one GeoDataFrame
    if intersections:
        result = gpd.GeoDataFrame(pd.concat(intersections, ignore_index=True))
    else:
        result = gpd.GeoDataFrame()  # Empty GeoDataFrame if no intersections

    municipality_processed = 0
    return result


intersections_5 = get_intersections(gdf_flood_5_reduced, gdf_municipality_reduced)
# Out:
# Grouping flood data by adm2_psgc and adm1_psgc...
# Converting municipality GeoDataFrame to Dask...
# Processing Municipality: a (adm2_psgc: 1.0, adm1_psgc: 1.0)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 34, in get_intersections.<locals>.process_municipality(municipality)
#      33 try:
# ---> 34     filtered_flood = flood_grouped.get_group((adm2_psgc, adm1_psgc))
#      35 except KeyError:
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1114, in BaseGroupBy.get_group(self, name, obj)
#    1113 if not len(inds):
# -> 1114     raise KeyError(name)
#    1116 if obj is None:
#
# KeyError: (1.0, 1.0)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:941, in BaseGroupBy._get_indices(self, names)
#     939 try:
#     940     # If the original grouper was a tuple
# --> 941     return [self.indices[name] for name in names]
#     942 except KeyError as err:
#     943     # turns out it wasn't a tuple
#
# KeyError: (1.0,)
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/utils.py:149, in raise_on_meta_error(funcname, udf)
#     148 try:
# --> 149     yield
#     150 except Exception as e:
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/dask_expr/_expr.py:4054, in emulate(func, udf, *args, **kwargs)
#    4053 with raise_on_meta_error(funcname(func), udf=udf):
# -> 4054     return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#
# Cell In[25], line 56, in get_intersections.<locals>.<lambda>(df)
#      55 # Apply the function to each municipality in parallel
# ---> 56 results = gdf_municipality.map_partitions(lambda df: [process_municipality(row) for _, row in df.iterrows()])
#      58 # Flatten the list of results and remove None values
#
# Cell In[25], line 37, in get_intersections.<locals>.process_municipality(municipality)
#      36 try:
# ---> 37     filtered_flood = flood_grouped.get_group((adm1_psgc,))
#      38 except KeyError:
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1112, in BaseGroupBy.get_group(self, name, obj)
#    1103         warnings.warn(
#    1104             "When grouping with a length-1 list-like, "
#    1105             "you will need to pass a length-1 tuple to get_group in a future "
#    (...)   1109             stacklevel=find_stack_level(),
#    1110         )
# -> 1112 inds = self._get_index(name)
#    1113 if not len(inds):
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:964, in BaseGroupBy._get_index(self, name)
#     961 """
#     962 Safe get index, translate keys for datelike to underlying repr.
#     963 """
# --> 964 return self._get_indices([name])[0]
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:948, in BaseGroupBy._get_indices(self, names)
#     944         msg = (
#     945             "must supply a same-length tuple to get_group "
#     946             "with multiple grouping keys"
#     947         )
# --> 948         raise ValueError(msg) from err
#     950 converters = [get_converter(s) for s in index_sample]
#
# ValueError: must supply a same-length tuple to get_group with multiple grouping keys
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 71
#      67     municipality_processed = 0
#      68     return result
# ---> 71 intersections_5 = get_intersections(gdf_flood_5_reduced, gdf_municipality_reduced)
#
# Cell In[25], line 56, in get_intersections(gdf_flood, gdf_municipality)
#      53     return intersection
#      55 # Apply the function to each municipality in parallel
# ---> 56 results = gdf_municipality.map_partitions(lambda df: [process_municipality(row) for _, row in df.iterrows()])
#      58 # Flatten the list of results and remove None values
#      59 intersections = [inter for sublist in results.compute() for inter in sublist if inter is not None]
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:1113, in FrameBase.map_partitions(self, func, meta, enforce_metadata, transform_divisions, clear_divisions, align_dataframes, parent_meta, *args, **kwargs)
#     988 @insert_meta_param_description(pad=12)
#     989 def map_partitions(
#     990     self,
#    (...)    999     **kwargs,
#    1000 ):
#    1001     """Apply a Python function to each partition
#    1002
#    1003     Parameters
#    (...)   1111     None as the division.
#    1112     """
# -> 1113     return map_partitions(
#    1114         func,
#    1115         self,
#    1116         *args,
#    1117         meta=meta,
#    1118         enforce_metadata=enforce_metadata,
#    1119         transform_divisions=transform_divisions,
#    1120         clear_divisions=clear_divisions,
#    1121         align_dataframes=align_dataframes,
#    1122         parent_meta=parent_meta,
#    1123         **kwargs,
#    1124     )
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:6186, in map_partitions(func, meta, enforce_metadata, transform_divisions, clear_divisions, align_dataframes, parent_meta, *args, **kwargs)
#    6172     raise NotImplementedError()
#    6173 new_expr = expr.MapPartitions(
#    6174     args[0],
#    6175     func,
#    (...)   6184     *args[1:],
#    6185 )
# -> 6186 return new_collection(new_expr)
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/_collections.py:8, in new_collection(expr)
#       6 def new_collection(expr):
#       7     """Create new collection from an expr"""
# ----> 8     meta = expr._meta
#       9     expr._name  # Ensure backend is imported
#      10     return get_collection_type(meta)(expr)
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/functools.py:998, in cached_property.__get__(self, instance, owner)
#     996 val = cache.get(self.attrname, _NOT_FOUND)
#     997 if val is _NOT_FOUND:
# --> 998     val = self.func(instance)
#     999     try:
#    1000         cache[self.attrname] = val
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/dask_expr/_expr.py:680, in MapPartitions._meta(self)
#     677 @functools.cached_property
#     678 def _meta(self):
#     679     meta = self.operand("meta")
# --> 680     return _get_meta_map_partitions(
#     681         self.args,
#     682         [e for e in self.args if isinstance(e, Expr)],
#     683         self.func,
#     684         self.kwargs,
#     685         meta,
#     686         self.parent_meta,
#     687     )
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/dask_expr/_expr.py:4068, in _get_meta_map_partitions(args, dfs, func, kwargs, meta, parent_meta)
#    4064 if meta is no_default:
#    4065     # Use non-normalized kwargs here, as we want the real values (not
#    4066     # delayed values)
#    4067     a = [meta_nonempty(arg._meta) if isinstance(arg, Expr) else arg for arg in args]
# -> 4068     meta = emulate(func, *a, udf=True, **kwargs)
#    4069     meta_is_emulated = True
#    4070 else:
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/dask_expr/_expr.py:4053, in emulate(func, udf, *args, **kwargs)
#    4048 def emulate(func, *args, udf=False, **kwargs):
#    4049     """
#    4050     Apply a function using args / kwargs. If arguments contain dd.DataFrame /
#    4051     dd.Series, using internal cache (``_meta``) for calculation
#    4052     """
# -> 4053     with raise_on_meta_error(funcname(func), udf=udf):
#    4054         return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/utils.py:170, in raise_on_meta_error(funcname, udf)
#     161 msg += (
#     162     "Original error is below:\n"
#     163     "------------------------\n"
#    (...)    167     "{2}"
#     168 )
#     169 msg = msg.format(f" in `{funcname}`" if funcname else "", repr(e), tb)
# --> 170 raise ValueError(msg) from e
#
# ValueError: Metadata inference failed in `lambda`.
#
# You have supplied a custom function and Dask is unable to
# determine the type of output that that function returns.
#
# To resolve this please provide a meta= keyword.
# The docstring of the Dask function you ran should have more information.
#
# Original error is below:
# ------------------------
# ValueError('must supply a same-length tuple to get_group with multiple grouping keys')
#
# Traceback:
# ---------
#   File "/data/students/ryan/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/utils.py", line 149, in raise_on_meta_error
#     yield
#   File "/data/students/ryan/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/dask/dataframe/dask_expr/_expr.py", line 4054, in emulate
#     return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3278644/3491018588.py", line 56, in <lambda>
#     results = gdf_municipality.map_partitions(lambda df: [process_municipality(row) for _, row in df.iterrows()])
#                                                           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3278644/3491018588.py", line 37, in process_municipality
#     filtered_flood = flood_grouped.get_group((adm1_psgc,))
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/data/students/ryan/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/pandas/core/groupby/groupby.py", line 1112, in get_group
#     inds = self._get_index(name)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/data/students/ryan/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/pandas/core/groupby/groupby.py", line 964, in _get_index
#     return self._get_indices([name])[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/data/students/ryan/anaconda3/envs/rapids-25.02/lib/python3.12/site-packages/pandas/core/groupby/groupby.py", line 948, in _get_indices
#     raise ValueError(msg) from err

# %%
intersections_5.get_group((102800000, 100000000), None)
# Out:
#        adm1_psgc    adm2_psgc  FloodRisk  \
# 150  100000000.0  102800000.0        1.0
# 151  100000000.0  102800000.0        2.0
# 152  100000000.0  102800000.0        3.0
#
#                                               geometry
# 150  MULTIPOLYGON (((251325 1972285, 251325 1972275...
# 151  MULTIPOLYGON (((251515 1972465, 251505 1972465...
# 152  MULTIPOLYGON (((251885 1972805, 251885 1972795...

# %%
# import geopandas as gpd

# def get_intersections(gdf_flood, gdf_municipality):
#     # Initialize an empty list to store the results of each intersection
#     intersections = []
#     municipality_processed = 0

#     # Iterate through each municipality in gdf_municipality
#     for _, municipality in gdf_municipality.iterrows():

#         # Get the current municipality's adm2_psgc
#         adm2_psgc = municipality['adm2_psgc']
#         adm1_psgc = municipality['adm1_psgc']

#         # Filter gdf_flood based on adm2_psgc first
#         filtered_flood = gdf_flood[gdf_flood['adm2_psgc'] == adm2_psgc]

#         # If no match on adm2_psgc, filter based on adm1_psgc
#         if filtered_flood.empty:
#             filtered_flood = gdf_flood[gdf_flood['adm1_psgc'] == adm1_psgc]
        
#         # If still no match, print a message and continue
#         if filtered_flood.empty:
#             print(f"No flood data found for {municipality['Municipality']}")
#             continue

#         # If there are rows left, perform the intersection
#         if not filtered_flood.empty:
#             # Convert the municipality row to a GeoDataFrame
#             municipality_gdf = gpd.GeoDataFrame([municipality], geometry='geometry', crs=gdf_flood.crs)

#             intersection = gpd.overlay(filtered_flood, municipality_gdf, how='intersection')
#             intersections.append(intersection)
        
#         municipality_processed += 1
#         print(f"Processed {municipality_processed}/{len(gdf_municipality)} municipalities.")

#         if municipality_processed == 5:
#             break

#     # Combine all the intersections into one GeoDataFrame (if there were any matches)
#     if intersections:
#         result = gpd.GeoDataFrame(pd.concat(intersections, ignore_index=True))
#     else:
#         result = gpd.GeoDataFrame()  # Empty GeoDataFrame if no intersections

#     return result

# intersections_5 = get_intersections(gdf_flood_5_reduced, gdf_municipality_reduced)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print("Processing intersections for 25-year flood data...")
intersections_25 = get_intersections(gdf_flood_25_reduced, gdf_municipality_reduced)
print("Processing intersections for 100-year flood data...")
intersections_100 = get_intersections(gdf_flood_100_reduced, gdf_municipality_reduced)

# %% [markdown]
# ### Sandbox Code

# %%
import geopandas as gpd
import concurrent.futures

municipality_processed = 0

def calculate_flood_percentage_per_municipality(municipality_gdf, flood_risk_gdf):
    """
    For each municipality, calculate the flood risk percentage (per flood level).
    Returns a dictionary with 'ID', '% level 1', '% level 2', '% level 3'.
    """
    global municipality_processed 

    flood_percentages = []

    # Iterate through each municipality and calculate the intersection with flood polygons
    for _, municipality in municipality_gdf.iterrows():
        # Perform the overlay (intersection) between municipality boundary and flood risk data
        intersection = gpd.overlay(flood_risk_gdf, municipality_gdf.iloc[[_]], how='intersection')

        # Calculate the total area of the municipality
        municipality_area = municipality.geometry.area
        
        # Count flood levels in the intersection
        flood_counts = intersection['FloodRisk'].value_counts()  # Assuming 'flood_risk' column has levels 1, 2, 3
        
        flood_percentages_for_municipality = {
            'ID': municipality['adm3_psgc'],
            'level_1': (flood_counts.get(1, 0) / municipality_area) * 100,
            'level_2': (flood_counts.get(2, 0) / municipality_area) * 100,
            'level_3': (flood_counts.get(3, 0) / municipality_area) * 100,
        }
        
        flood_percentages.append(flood_percentages_for_municipality)

        municipality_processed += 1
        print("Municipalities Processed: ", municipality_processed)
    
    return flood_percentages

def calculate_flood_percentage_parallel(municipality_gdf, flood_risk_gdf):
    """
    Parallelized version of calculating flood risk percentages for each municipality.
    Returns a GeoDataFrame with 'ID', '% level 1', '% level 2', '% level 3'.
    """
    global municipality_processed 
    
    def calculate_for_municipality(municipality_index):
        municipality = municipality_gdf.iloc[municipality_index:municipality_index+1]
        return calculate_flood_percentage_per_municipality(municipality, flood_risk_gdf)

    # Create a list of indices for municipalities
    municipality_indices = range(len(municipality_gdf))
    
    # Use concurrent futures for parallelization
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(calculate_for_municipality, municipality_indices))

    # Flatten the results and convert to DataFrame
    flat_results = [item for sublist in results for item in sublist]
    flood_percentages_df = pd.DataFrame(flat_results)

    # Create a GeoDataFrame with the result
    result_gdf = municipality_gdf[['geometry']].copy()  # Retain the geometry column
    result_gdf = result_gdf.join(flood_percentages_df.set_index('ID'), on='municipality_id')

    municipality_processed = 0

    return result_gdf

# %%
# municipality_gdf = gdf_municipality.sample(frac=0.01, random_state=42).reset_index(drop=True)
# flood_risk_gdf = gdf_flood_5.sample(frac=0.01, random_state=42).reset_index(drop=True)

# Parallelize the flood risk percentage calculation for all municipalities
flood_percentage_5_gdf = calculate_flood_percentage_parallel(gdf_municipality, gdf_flood_5)

flood_percentage_5_gdf
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# import geopandas as gpd

# def calculate_flood_percentage_per_municipality(municipality_gdf, flood_risk_gdf, test=True):
#     """
#     For each municipality, calculate the flood risk percentage (per flood level).
#     """
#     flood_percentages = []
#     municipality_ids = []

#     # Select only geometry and adm3_psgc columns from municipality_gdf
#     municipality_gdf = municipality_gdf[["adm3_psgc","geometry"]]

#     if test:
#         municipality_gdf = municipality_gdf.sample(frac=0.01, random_state=42).reset_index(drop=True)
#         flood_risk_gdf = flood_risk_gdf.sample(frac=0.01, random_state=42).reset_index(drop=True)


#     # Iterate through each municipality and calculate the intersection with flood polygons
#     for _, municipality in municipality_gdf.iterrows():
#         # Perform the overlay (intersection) between municipality boundary and flood risk data
#         intersection = gpd.overlay(flood_risk_gdf, municipality_gdf.iloc[[_]], how='intersection')

#         # Calculate the total area of the municipality
#         municipality_area = municipality.geometry.area
        
#         # Count flood levels in the intersection
#         flood_counts = intersection['flood_risk'].value_counts()  # Assuming 'flood_risk' column has levels 1, 2, 3
        
#         flood_percentages_for_municipality = {}
        
#         for flood_level in range(1, 4):  # Assuming flood levels are 1, 2, 3
#             flood_area = flood_counts.get(flood_level, 0)
#             flood_percentage = (flood_area / municipality_area) * 100
#             flood_percentages_for_municipality[flood_level] = flood_percentage
        
#         municipality_ids.append(id)
#         flood_percentages.append(flood_percentages_for_municipality)
    
#     return flood_percentages

# %%
import os
import torch

# No nvlink
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 

# Use a specific GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "4,2,3,5"

# %%
import cuspatial
import geopandas as gpd
import cudf
import numpy as np
import gc

# def extract_polygon_coordinates(gdf):
#     """Extracts polygon coordinates in a format compatible with cuspatial."""
#     polygon_x = []
#     polygon_y = []
#     ring_start_indices = [0]  # Start index for each polygon

#     for geom in gdf.geometry:
#         if geom.is_empty:
#             continue

#         # Extract exterior ring coordinates
#         x_coords, y_coords = geom.exterior.xy
#         polygon_x.extend(x_coords)
#         polygon_y.extend(y_coords)
#         ring_start_indices.append(len(polygon_x))  # New polygon starts here

#     return cudf.Series(polygon_x), cudf.Series(polygon_y), cudf.Series(ring_start_indices[:-1])


def rasterize_polygons_gpu(gdf, test=False, resolution=250):
    """
    Approximate rasterization by converting polygons into points and using GPU queries.
    """
    if test:
        gdf = gdf.sample(frac=0.01, random_state=42)

    # ✅ Explode MultiPolygons into separate Polygons
    
    print("Exploding polygons...")
    gdf = gdf.explode(index_parts=False).reset_index(drop=True)
    print("Converting to cuDF DataFrame...")
    gpu_dataframe = cuspatial.from_geopandas(gdf)

    # print("Calculating bounds...")
    # xmin, ymin, xmax, ymax = gdf.total_bounds
    # x_coords = np.arange(xmin, xmax, resolution)
    # y_coords = np.arange(ymin, ymax, resolution)

    # Generate a raster grid of points
    print("Generating grid of points...")
    x_points = np.linspace(gdf.total_bounds[0], gdf.total_bounds[2], num=resolution)
    y_points = np.linspace(gdf.total_bounds[1], gdf.total_bounds[3], num=resolution)
    xx, yy = np.meshgrid(x_points, y_points)

    # Convert to cuDF DataFrame and remove NaNs
    cdf_points = cudf.DataFrame({"x": xx.ravel(), "y": yy.ravel()}).dropna()

    # Ensure interleaving for cuSpatial
    print("Creating cuDF DataFrame for points...")
    xy = cdf_points.interleave_columns()
    cdf_points = cuspatial.GeoSeries.from_points_xy(xy)

    geometry = gpu_dataframe['geometry']


    # Process in batches of 30 polygons
    print("Performing point-in-polygon test...")

    batch_size = 30
    num_batches = len(geometry) // batch_size + (len(geometry) % batch_size > 0)

    results = []

    for i in range(num_batches):
        print(f"Processing batch {i + 1}/{num_batches}...")
        batch_polygons = geometry.iloc[i * batch_size : (i + 1) * batch_size]
        if len(batch_polygons) == 0:
            continue
        
        points_in_polygon = cuspatial.point_in_polygon(cdf_points, batch_polygons)
        results.append(points_in_polygon)

    # Merge all batch results into one DataFrame (each column corresponds to a batch of polygons)
    final_result = cudf.concat(results, axis=1)

    # Reduce across polygons (sum to count overlaps, or max to get a binary raster)
    raster_values = final_result.max(axis=1).to_numpy()  # Use max() for a binary mask

    # Reshape to match grid dimensions
    raster = raster_values.reshape(len(y_points), len(x_points))

    del final_result  # Delete variables no longer needed
    gc.collect()  # Force garbage collection
    
    return raster

# %%
import cupy as cp

def process_flood_risk(flood_gdf, muni_gdf, test=False):
    # Rasterize polygons on GPU
    print("Rasterizing flood polygons...")
    flood_raster_gpu = rasterize_polygons_gpu(flood_gdf, test=test)
    print("Rasterizing municipality polygons...")
    muni_raster_gpu = rasterize_polygons_gpu(muni_gdf, test=test)

    # Ensure flood_raster_gpu and muni_raster_gpu have the same shape BEFORE analysis
    if flood_raster_gpu.shape != muni_raster_gpu.shape:
        print("Flood and municipality rasters must have the same shape!")

    # Convert to cupy arrays (if they are not already)
    muni_raster_gpu = cp.asarray(muni_raster_gpu)  # Ensure it's a cupy array
    flood_raster_gpu = cp.asarray(flood_raster_gpu)  # Ensure it's a cupy array

    # Compute flood percentages without align()
    print("Computing flood percentages...")
    flood_percentages = cp.bincount(
        muni_raster_gpu.ravel(),  # Municipality categories
        weights=flood_raster_gpu.ravel()  # Flood intensities
    )

    return muni_raster_gpu, flood_raster_gpu, flood_percentages

# Process flood risk data
print("Processing 5-year flood risk data...")
muni_raster_gpu, flood_raster_gpu, flood_5_percentages = process_flood_risk(gdf_flood_5, gdf_municipality, test=True)
# Out:
# Processing 5-year flood risk data...
# Rasterizing flood polygons...
# Exploding polygons...
# Converting to cuDF DataFrame...
# Generating grid of points...
# Creating cuDF DataFrame for points...
# Performing point-in-polygon test...
# Processing batch 1/1661...
# Processing batch 2/1661...
# Processing batch 3/1661...
# Processing batch 4/1661...
# Processing batch 5/1661...
# Processing batch 6/1661...
# Processing batch 7/1661...
# Processing batch 8/1661...
# Processing batch 9/1661...
# Processing batch 10/1661...
# Processing batch 11/1661...
# Processing batch 12/1661...
# Processing batch 13/1661...
# Processing batch 14/1661...
# Processing batch 15/1661...
# Processing batch 16/1661...
# Processing batch 17/1661...
# Processing batch 18/1661...
# Processing batch 19/1661...
# Processing batch 20/1661...
# Processing batch 21/1661...
# Processing batch 22/1661...
# Processing batch 23/1661...
# Processing batch 24/1661...
# Processing batch 25/1661...
# Processing batch 26/1661...
# Processing batch 27/1661...
# Processing batch 28/1661...
# Processing batch 29/1661...
# Processing batch 30/1661...
# Processing batch 31/1661...
# Processing batch 32/1661...
# Processing batch 33/1661...
# Processing batch 34/1661...
# Processing batch 35/1661...
# Processing batch 36/1661...
# Processing batch 37/1661...
# Processing batch 38/1661...
# Processing batch 39/1661...
# Processing batch 40/1661...
# Processing batch 41/1661...
# Processing batch 42/1661...
# Processing batch 43/1661...
# Processing batch 44/1661...
# Processing batch 45/1661...
# Processing batch 46/1661...
# Processing batch 47/1661...
# Processing batch 48/1661...
# Processing batch 49/1661...
# Processing batch 50/1661...
# Processing batch 51/1661...
# Processing batch 52/1661...
# Processing batch 53/1661...
# Processing batch 54/1661...
# Processing batch 55/1661...
# Processing batch 56/1661...
# Processing batch 57/1661...
# Processing batch 58/1661...
# Processing batch 59/1661...
# Processing batch 60/1661...
# Processing batch 61/1661...
# Processing batch 62/1661...
# Processing batch 63/1661...
# Processing batch 64/1661...
# Processing batch 65/1661...
# Processing batch 66/1661...
# Processing batch 67/1661...
# Processing batch 68/1661...
# Processing batch 69/1661...
# Processing batch 70/1661...
# Processing batch 71/1661...
# Processing batch 72/1661...
# Processing batch 73/1661...
# Processing batch 74/1661...
# Processing batch 75/1661...
# Processing batch 76/1661...
# Processing batch 77/1661...
# Processing batch 78/1661...
# Processing batch 79/1661...
# Processing batch 80/1661...
# Processing batch 81/1661...
# Processing batch 82/1661...
# Processing batch 83/1661...
# Processing batch 84/1661...
# Processing batch 85/1661...
# Processing batch 86/1661...
# Processing batch 87/1661...
# Processing batch 88/1661...
# Processing batch 89/1661...
# Processing batch 90/1661...
# Processing batch 91/1661...
# Processing batch 92/1661...
# Processing batch 93/1661...
# Processing batch 94/1661...
# Processing batch 95/1661...
# Processing batch 96/1661...
# Processing batch 97/1661...
# Processing batch 98/1661...
# Processing batch 99/1661...
# Processing batch 100/1661...
# Processing batch 101/1661...
# Processing batch 102/1661...
# Processing batch 103/1661...
# Processing batch 104/1661...
# Processing batch 105/1661...
# Processing batch 106/1661...
# Processing batch 107/1661...
# Processing batch 108/1661...
# Processing batch 109/1661...
# Processing batch 110/1661...
# Processing batch 111/1661...
# Processing batch 112/1661...
# Processing batch 113/1661...
# Processing batch 114/1661...
# Processing batch 115/1661...
# Processing batch 116/1661...
# Processing batch 117/1661...
# Processing batch 118/1661...
# Processing batch 119/1661...
# Processing batch 120/1661...
# Processing batch 121/1661...
# Processing batch 122/1661...
# Processing batch 123/1661...
# Processing batch 124/1661...
# Processing batch 125/1661...
# Processing batch 126/1661...
# Processing batch 127/1661...
# Processing batch 128/1661...
# Processing batch 129/1661...
# Processing batch 130/1661...
# Processing batch 131/1661...
# Processing batch 132/1661...
# Processing batch 133/1661...
# Processing batch 134/1661...
# Processing batch 135/1661...
# Processing batch 136/1661...
# Processing batch 137/1661...
# Processing batch 138/1661...
# Processing batch 139/1661...
# Processing batch 140/1661...
# Processing batch 141/1661...
# Processing batch 142/1661...
# Processing batch 143/1661...
# Processing batch 144/1661...
# Processing batch 145/1661...
# Processing batch 146/1661...
# Processing batch 147/1661...
# Processing batch 148/1661...
# Processing batch 149/1661...
# Processing batch 150/1661...
# Processing batch 151/1661...
# Processing batch 152/1661...
# Processing batch 153/1661...
# Processing batch 154/1661...
# Processing batch 155/1661...
# Processing batch 156/1661...
# Processing batch 157/1661...
# Processing batch 158/1661...
# Processing batch 159/1661...
# Processing batch 160/1661...
# Processing batch 161/1661...
# Processing batch 162/1661...
# Processing batch 163/1661...
# Processing batch 164/1661...
# Processing batch 165/1661...
# Processing batch 166/1661...
# Processing batch 167/1661...
# Processing batch 168/1661...
# Processing batch 169/1661...
# Processing batch 170/1661...
# Processing batch 171/1661...
# Processing batch 172/1661...
# Processing batch 173/1661...
# Processing batch 174/1661...
# Processing batch 175/1661...
# Processing batch 176/1661...
# Processing batch 177/1661...
# Processing batch 178/1661...
# Processing batch 179/1661...
# Processing batch 180/1661...
# Processing batch 181/1661...
# Processing batch 182/1661...
# Processing batch 183/1661...
# Processing batch 184/1661...
# Processing batch 185/1661...
# Processing batch 186/1661...
# Processing batch 187/1661...
# Processing batch 188/1661...
# Processing batch 189/1661...
# Processing batch 190/1661...
# Processing batch 191/1661...
# Processing batch 192/1661...
# Processing batch 193/1661...
# Processing batch 194/1661...
# Processing batch 195/1661...
# Processing batch 196/1661...
# Processing batch 197/1661...
# Processing batch 198/1661...
# Processing batch 199/1661...
# Processing batch 200/1661...
# Processing batch 201/1661...
# Processing batch 202/1661...
# Processing batch 203/1661...
# Processing batch 204/1661...
# Processing batch 205/1661...
# Processing batch 206/1661...
# Processing batch 207/1661...
# Processing batch 208/1661...
# Processing batch 209/1661...
# Processing batch 210/1661...
# Processing batch 211/1661...
# Processing batch 212/1661...
# Processing batch 213/1661...
# Processing batch 214/1661...
# Processing batch 215/1661...
# Processing batch 216/1661...
# Processing batch 217/1661...
# Processing batch 218/1661...
# Processing batch 219/1661...
# Processing batch 220/1661...
# Processing batch 221/1661...
# Processing batch 222/1661...
# Processing batch 223/1661...
# Processing batch 224/1661...
# Processing batch 225/1661...
# Processing batch 226/1661...
# Processing batch 227/1661...
# Processing batch 228/1661...
# Processing batch 229/1661...
# Processing batch 230/1661...
# Processing batch 231/1661...
# Processing batch 232/1661...
# Processing batch 233/1661...
# Processing batch 234/1661...
# Processing batch 235/1661...
# Processing batch 236/1661...
# Processing batch 237/1661...
# Processing batch 238/1661...
# Processing batch 239/1661...
# Processing batch 240/1661...
# Processing batch 241/1661...
# Processing batch 242/1661...
# Processing batch 243/1661...
# Processing batch 244/1661...
# Processing batch 245/1661...
# Processing batch 246/1661...
# Processing batch 247/1661...
# Processing batch 248/1661...
# Processing batch 249/1661...
# Processing batch 250/1661...
# Processing batch 251/1661...
# Processing batch 252/1661...
# Processing batch 253/1661...
# Processing batch 254/1661...
# Processing batch 255/1661...
# Processing batch 256/1661...
# Processing batch 257/1661...
# Processing batch 258/1661...
# Processing batch 259/1661...
# Processing batch 260/1661...
# Processing batch 261/1661...
# Processing batch 262/1661...
# Processing batch 263/1661...
# Processing batch 264/1661...
# Processing batch 265/1661...
# Processing batch 266/1661...
# Processing batch 267/1661...
# Processing batch 268/1661...
# Processing batch 269/1661...
# Processing batch 270/1661...
# Processing batch 271/1661...
# Processing batch 272/1661...
# Processing batch 273/1661...
# Processing batch 274/1661...
# Processing batch 275/1661...
# Processing batch 276/1661...
# Processing batch 277/1661...
# Processing batch 278/1661...
# Processing batch 279/1661...
# Processing batch 280/1661...
# Processing batch 281/1661...
# Processing batch 282/1661...
# Processing batch 283/1661...
# Processing batch 284/1661...
# Processing batch 285/1661...
# Processing batch 286/1661...
# Processing batch 287/1661...
# Processing batch 288/1661...
# Processing batch 289/1661...
# Processing batch 290/1661...
# Processing batch 291/1661...
# Processing batch 292/1661...
# Processing batch 293/1661...
# Processing batch 294/1661...
# Processing batch 295/1661...
# Processing batch 296/1661...
# Processing batch 297/1661...
# Processing batch 298/1661...
# Processing batch 299/1661...
# Processing batch 300/1661...
# Processing batch 301/1661...
# Processing batch 302/1661...
# Processing batch 303/1661...
# Processing batch 304/1661...
# Processing batch 305/1661...
# Processing batch 306/1661...
# Processing batch 307/1661...
# Processing batch 308/1661...
# Processing batch 309/1661...
# Processing batch 310/1661...
# Processing batch 311/1661...
# Processing batch 312/1661...
# Processing batch 313/1661...
# Processing batch 314/1661...
# Processing batch 315/1661...
# Processing batch 316/1661...
# Processing batch 317/1661...
# Processing batch 318/1661...
# Processing batch 319/1661...
# Processing batch 320/1661...
# Processing batch 321/1661...
# Processing batch 322/1661...
# Processing batch 323/1661...
# Processing batch 324/1661...
# Processing batch 325/1661...
# Processing batch 326/1661...
# Processing batch 327/1661...
# Processing batch 328/1661...
# Processing batch 329/1661...
# Processing batch 330/1661...
# Processing batch 331/1661...
# Processing batch 332/1661...
# Processing batch 333/1661...
# Processing batch 334/1661...
# Processing batch 335/1661...
# Processing batch 336/1661...
# Processing batch 337/1661...
# Processing batch 338/1661...
# Processing batch 339/1661...
# Processing batch 340/1661...
# Processing batch 341/1661...
# Processing batch 342/1661...
# Processing batch 343/1661...
# Processing batch 344/1661...
# Processing batch 345/1661...
# Processing batch 346/1661...
# Processing batch 347/1661...
# Processing batch 348/1661...
# Processing batch 349/1661...
# Processing batch 350/1661...
# Processing batch 351/1661...
# Processing batch 352/1661...
# Processing batch 353/1661...
# Processing batch 354/1661...
# Processing batch 355/1661...
# Processing batch 356/1661...
# Processing batch 357/1661...
# Processing batch 358/1661...
# Processing batch 359/1661...
# Processing batch 360/1661...
# Processing batch 361/1661...
# Processing batch 362/1661...
# Processing batch 363/1661...
# Processing batch 364/1661...
# Processing batch 365/1661...
# Processing batch 366/1661...
# Processing batch 367/1661...
# Processing batch 368/1661...
# Processing batch 369/1661...
# Processing batch 370/1661...
# Processing batch 371/1661...
# Processing batch 372/1661...
# Processing batch 373/1661...
# Processing batch 374/1661...
# Processing batch 375/1661...
# Processing batch 376/1661...
# Processing batch 377/1661...
# Processing batch 378/1661...
# Processing batch 379/1661...
# Processing batch 380/1661...
# Processing batch 381/1661...
# Processing batch 382/1661...
# Processing batch 383/1661...
# Processing batch 384/1661...
# Processing batch 385/1661...
# Processing batch 386/1661...
# Processing batch 387/1661...
# Processing batch 388/1661...
# Processing batch 389/1661...
# Processing batch 390/1661...
# Processing batch 391/1661...
# Processing batch 392/1661...
# Processing batch 393/1661...
# Processing batch 394/1661...
# Processing batch 395/1661...
# Processing batch 396/1661...
# Processing batch 397/1661...
# Processing batch 398/1661...
# Processing batch 399/1661...
# Processing batch 400/1661...
# Processing batch 401/1661...
# Processing batch 402/1661...
# Processing batch 403/1661...
# Processing batch 404/1661...
# Processing batch 405/1661...
# Processing batch 406/1661...
# Processing batch 407/1661...
# Processing batch 408/1661...
# Processing batch 409/1661...
# Processing batch 410/1661...
# Processing batch 411/1661...
# Processing batch 412/1661...
# Processing batch 413/1661...
# Processing batch 414/1661...
# Processing batch 415/1661...
# Processing batch 416/1661...
# Processing batch 417/1661...
# Processing batch 418/1661...
# Processing batch 419/1661...
# Processing batch 420/1661...
# Processing batch 421/1661...
# Processing batch 422/1661...
# Processing batch 423/1661...
# Processing batch 424/1661...
# Processing batch 425/1661...
# Processing batch 426/1661...
# Processing batch 427/1661...
# Processing batch 428/1661...
# Processing batch 429/1661...
# Processing batch 430/1661...
# Processing batch 431/1661...
# Processing batch 432/1661...
# Processing batch 433/1661...
# Processing batch 434/1661...
# Processing batch 435/1661...
# Processing batch 436/1661...
# Processing batch 437/1661...
# Processing batch 438/1661...
# Processing batch 439/1661...
# Processing batch 440/1661...
# Processing batch 441/1661...
# Processing batch 442/1661...
# Processing batch 443/1661...
# Processing batch 444/1661...
# Processing batch 445/1661...
# Processing batch 446/1661...
# Processing batch 447/1661...
# Processing batch 448/1661...
# Processing batch 449/1661...
# Processing batch 450/1661...
# Processing batch 451/1661...
# Processing batch 452/1661...
# Processing batch 453/1661...
# Processing batch 454/1661...
# Processing batch 455/1661...
# Processing batch 456/1661...
# Processing batch 457/1661...
# Processing batch 458/1661...
# Processing batch 459/1661...
# Processing batch 460/1661...
# Processing batch 461/1661...
# Processing batch 462/1661...
# Processing batch 463/1661...
# Processing batch 464/1661...
# Processing batch 465/1661...
# Processing batch 466/1661...
# Processing batch 467/1661...
# Processing batch 468/1661...
# Processing batch 469/1661...
# Processing batch 470/1661...
# Processing batch 471/1661...
# Processing batch 472/1661...
# Processing batch 473/1661...
# Processing batch 474/1661...
# Processing batch 475/1661...
# Processing batch 476/1661...
# Processing batch 477/1661...
# Processing batch 478/1661...
# Processing batch 479/1661...
# Processing batch 480/1661...
# Processing batch 481/1661...
# Processing batch 482/1661...
# Processing batch 483/1661...
# Processing batch 484/1661...
# Processing batch 485/1661...
# Processing batch 486/1661...
# Processing batch 487/1661...
# Processing batch 488/1661...
# Processing batch 489/1661...
# Processing batch 490/1661...
# Processing batch 491/1661...
# Processing batch 492/1661...
# Processing batch 493/1661...
# Processing batch 494/1661...
# Processing batch 495/1661...
# Processing batch 496/1661...
# Processing batch 497/1661...
# Processing batch 498/1661...
# Processing batch 499/1661...
# Processing batch 500/1661...
# Processing batch 501/1661...
# Processing batch 502/1661...
# Processing batch 503/1661...
# Processing batch 504/1661...
# Processing batch 505/1661...
# Processing batch 506/1661...
# Processing batch 507/1661...
# Processing batch 508/1661...
# Processing batch 509/1661...
# Processing batch 510/1661...
# Processing batch 511/1661...
# Processing batch 512/1661...
# Processing batch 513/1661...
# Processing batch 514/1661...
# Processing batch 515/1661...
# Processing batch 516/1661...
# Processing batch 517/1661...
# Processing batch 518/1661...
# Processing batch 519/1661...
# Processing batch 520/1661...
# Processing batch 521/1661...
# Processing batch 522/1661...
# Processing batch 523/1661...
# Processing batch 524/1661...
# Processing batch 525/1661...
# Processing batch 526/1661...
# Processing batch 527/1661...
# Processing batch 528/1661...
# Processing batch 529/1661...
# Processing batch 530/1661...
# Processing batch 531/1661...
# Processing batch 532/1661...
# Processing batch 533/1661...
# Processing batch 534/1661...
# Processing batch 535/1661...
# Processing batch 536/1661...
# Processing batch 537/1661...
# Processing batch 538/1661...
# Processing batch 539/1661...
# Processing batch 540/1661...
# Processing batch 541/1661...
# Processing batch 542/1661...
# Processing batch 543/1661...
# Processing batch 544/1661...
# Processing batch 545/1661...
# Processing batch 546/1661...
# Processing batch 547/1661...
# Processing batch 548/1661...
# Processing batch 549/1661...
# Processing batch 550/1661...
# Processing batch 551/1661...
# Processing batch 552/1661...
# Processing batch 553/1661...
# Processing batch 554/1661...
# Processing batch 555/1661...
# Processing batch 556/1661...
# Processing batch 557/1661...
# Processing batch 558/1661...
# Processing batch 559/1661...
# Processing batch 560/1661...
# Processing batch 561/1661...
# Processing batch 562/1661...
# Processing batch 563/1661...
# Processing batch 564/1661...
# Processing batch 565/1661...
# Processing batch 566/1661...
# Processing batch 567/1661...
# Processing batch 568/1661...
# Processing batch 569/1661...
# Processing batch 570/1661...
# Processing batch 571/1661...
# Processing batch 572/1661...
# Processing batch 573/1661...
# Processing batch 574/1661...
# Processing batch 575/1661...
# Processing batch 576/1661...
# Processing batch 577/1661...
# Processing batch 578/1661...
# Processing batch 579/1661...
# Processing batch 580/1661...
# Processing batch 581/1661...
# Processing batch 582/1661...
# Processing batch 583/1661...
# Processing batch 584/1661...
# Processing batch 585/1661...
# Processing batch 586/1661...
# Processing batch 587/1661...
# Processing batch 588/1661...
# Processing batch 589/1661...
# Processing batch 590/1661...
# Processing batch 591/1661...
# Processing batch 592/1661...
# Processing batch 593/1661...
# Processing batch 594/1661...
# Processing batch 595/1661...
# Processing batch 596/1661...
# Processing batch 597/1661...
# Processing batch 598/1661...
# Processing batch 599/1661...
# Processing batch 600/1661...
# Processing batch 601/1661...
# Processing batch 602/1661...
# Processing batch 603/1661...
# Processing batch 604/1661...
# Processing batch 605/1661...
# Processing batch 606/1661...
# Processing batch 607/1661...
# Processing batch 608/1661...
# Processing batch 609/1661...
# Processing batch 610/1661...
# Processing batch 611/1661...
# Processing batch 612/1661...
# Processing batch 613/1661...
# Processing batch 614/1661...
# Processing batch 615/1661...
# Processing batch 616/1661...
# Processing batch 617/1661...
# Processing batch 618/1661...
# Processing batch 619/1661...
# Processing batch 620/1661...
# Processing batch 621/1661...
# Processing batch 622/1661...
# Processing batch 623/1661...
# Processing batch 624/1661...
# Processing batch 625/1661...
# Processing batch 626/1661...
# Processing batch 627/1661...
# Processing batch 628/1661...
# Processing batch 629/1661...
# Processing batch 630/1661...
# Processing batch 631/1661...
# Processing batch 632/1661...
# Processing batch 633/1661...
# Processing batch 634/1661...
# Processing batch 635/1661...
# Processing batch 636/1661...
# Processing batch 637/1661...
# Processing batch 638/1661...
# Processing batch 639/1661...
# Processing batch 640/1661...
# Processing batch 641/1661...
# Processing batch 642/1661...
# Processing batch 643/1661...
# Processing batch 644/1661...
# Processing batch 645/1661...
# Processing batch 646/1661...
# Processing batch 647/1661...
# Processing batch 648/1661...
# Processing batch 649/1661...
# Processing batch 650/1661...
# Processing batch 651/1661...
# Processing batch 652/1661...
# Processing batch 653/1661...
# Processing batch 654/1661...
# Processing batch 655/1661...
# Processing batch 656/1661...
# Processing batch 657/1661...
# Processing batch 658/1661...
# Processing batch 659/1661...
# Processing batch 660/1661...
# Processing batch 661/1661...
# Processing batch 662/1661...
# Processing batch 663/1661...
# Processing batch 664/1661...
# Processing batch 665/1661...
# Processing batch 666/1661...
# Processing batch 667/1661...
# Processing batch 668/1661...
# Processing batch 669/1661...
# Processing batch 670/1661...
# Processing batch 671/1661...
# Processing batch 672/1661...
# Processing batch 673/1661...
# Processing batch 674/1661...
# Processing batch 675/1661...
# Processing batch 676/1661...
# Processing batch 677/1661...
# Processing batch 678/1661...
# Processing batch 679/1661...
# Processing batch 680/1661...
# Processing batch 681/1661...
# Processing batch 682/1661...
# Processing batch 683/1661...
# Processing batch 684/1661...
# Processing batch 685/1661...
# Processing batch 686/1661...
# Processing batch 687/1661...
# Processing batch 688/1661...
# Processing batch 689/1661...
# Processing batch 690/1661...
# Processing batch 691/1661...
# Processing batch 692/1661...
# Processing batch 693/1661...
# Processing batch 694/1661...
# Processing batch 695/1661...
# Processing batch 696/1661...
# Processing batch 697/1661...
# Processing batch 698/1661...
# Processing batch 699/1661...
# Processing batch 700/1661...
# Processing batch 701/1661...
# Processing batch 702/1661...
# Processing batch 703/1661...
# Processing batch 704/1661...
# Processing batch 705/1661...
# Processing batch 706/1661...
# Processing batch 707/1661...
# Processing batch 708/1661...
# Processing batch 709/1661...
# Processing batch 710/1661...
# Processing batch 711/1661...
# Processing batch 712/1661...
# Processing batch 713/1661...
# Processing batch 714/1661...
# Processing batch 715/1661...
# Processing batch 716/1661...
# Processing batch 717/1661...
# Processing batch 718/1661...
# Processing batch 719/1661...
# Processing batch 720/1661...
# Processing batch 721/1661...
# Processing batch 722/1661...
# Processing batch 723/1661...
# Processing batch 724/1661...
# Processing batch 725/1661...
# Processing batch 726/1661...
# Processing batch 727/1661...
# Processing batch 728/1661...
# Processing batch 729/1661...
# Processing batch 730/1661...
# Processing batch 731/1661...
# Processing batch 732/1661...
# Processing batch 733/1661...
# Processing batch 734/1661...
# Processing batch 735/1661...
# Processing batch 736/1661...
# Processing batch 737/1661...
# Processing batch 738/1661...
# Processing batch 739/1661...
# Processing batch 740/1661...
# Processing batch 741/1661...
# Processing batch 742/1661...
# Processing batch 743/1661...
# Processing batch 744/1661...
# Processing batch 745/1661...
# Processing batch 746/1661...
# Processing batch 747/1661...
# Processing batch 748/1661...
# Processing batch 749/1661...
# Processing batch 750/1661...
# Processing batch 751/1661...
# Processing batch 752/1661...
# Processing batch 753/1661...
# Processing batch 754/1661...
# Processing batch 755/1661...
# Processing batch 756/1661...
# Processing batch 757/1661...
# Processing batch 758/1661...
# Processing batch 759/1661...
# Processing batch 760/1661...
# Processing batch 761/1661...
# Processing batch 762/1661...
# Processing batch 763/1661...
# Processing batch 764/1661...
# Processing batch 765/1661...
# Processing batch 766/1661...
# Processing batch 767/1661...
# Processing batch 768/1661...
# Processing batch 769/1661...
# Processing batch 770/1661...
# Processing batch 771/1661...
# Processing batch 772/1661...
# Processing batch 773/1661...
# Processing batch 774/1661...
# Processing batch 775/1661...
# Processing batch 776/1661...
# Processing batch 777/1661...
# Processing batch 778/1661...
# Processing batch 779/1661...
# Processing batch 780/1661...
# Processing batch 781/1661...
# Processing batch 782/1661...
# Processing batch 783/1661...
# Processing batch 784/1661...
# Processing batch 785/1661...
# Processing batch 786/1661...
# Processing batch 787/1661...
# Processing batch 788/1661...
# Processing batch 789/1661...
# Processing batch 790/1661...
# Processing batch 791/1661...
# Processing batch 792/1661...
# Processing batch 793/1661...
# Processing batch 794/1661...
# Processing batch 795/1661...
# Processing batch 796/1661...
# Processing batch 797/1661...
# Processing batch 798/1661...
# Processing batch 799/1661...
# Processing batch 800/1661...
# Processing batch 801/1661...
# Processing batch 802/1661...
# Processing batch 803/1661...
# Processing batch 804/1661...
# Processing batch 805/1661...
# Processing batch 806/1661...
# Processing batch 807/1661...
# Processing batch 808/1661...
# Processing batch 809/1661...
# Processing batch 810/1661...
# Processing batch 811/1661...
# Processing batch 812/1661...
# Processing batch 813/1661...
# Processing batch 814/1661...
# Processing batch 815/1661...
# Processing batch 816/1661...
# Processing batch 817/1661...
# Processing batch 818/1661...
# Processing batch 819/1661...
# Processing batch 820/1661...
# Processing batch 821/1661...
# Processing batch 822/1661...
# Processing batch 823/1661...
# Processing batch 824/1661...
# Processing batch 825/1661...
# Processing batch 826/1661...
# Processing batch 827/1661...
# Processing batch 828/1661...
# Processing batch 829/1661...
# Processing batch 830/1661...
# Processing batch 831/1661...
# Processing batch 832/1661...
# Processing batch 833/1661...
# Processing batch 834/1661...
# Processing batch 835/1661...
# Processing batch 836/1661...
# Processing batch 837/1661...
# Processing batch 838/1661...
# Processing batch 839/1661...
# Processing batch 840/1661...
# Processing batch 841/1661...
# Processing batch 842/1661...
# Processing batch 843/1661...
# Processing batch 844/1661...
# Processing batch 845/1661...
# Processing batch 846/1661...
# Processing batch 847/1661...
# Processing batch 848/1661...
# Processing batch 849/1661...
# Processing batch 850/1661...
# Processing batch 851/1661...
# Processing batch 852/1661...
# Processing batch 853/1661...
# Processing batch 854/1661...
# Processing batch 855/1661...
# Processing batch 856/1661...
# Processing batch 857/1661...
# Processing batch 858/1661...
# Processing batch 859/1661...
# Processing batch 860/1661...
# Processing batch 861/1661...
# Processing batch 862/1661...
# Processing batch 863/1661...
# Processing batch 864/1661...
# Processing batch 865/1661...
# Processing batch 866/1661...
# Processing batch 867/1661...
# Processing batch 868/1661...
# Processing batch 869/1661...
# Processing batch 870/1661...
# Processing batch 871/1661...
# Processing batch 872/1661...
# Processing batch 873/1661...
# Processing batch 874/1661...
# Processing batch 875/1661...
# Processing batch 876/1661...
# Processing batch 877/1661...
# Processing batch 878/1661...
# Processing batch 879/1661...
# Processing batch 880/1661...
# Processing batch 881/1661...
# Processing batch 882/1661...
# Processing batch 883/1661...
# Processing batch 884/1661...
# Processing batch 885/1661...
# Processing batch 886/1661...
# Processing batch 887/1661...
# Processing batch 888/1661...
# Processing batch 889/1661...
# Processing batch 890/1661...
# Processing batch 891/1661...
# Processing batch 892/1661...
# Processing batch 893/1661...
# Processing batch 894/1661...
# Processing batch 895/1661...
# Processing batch 896/1661...
# Processing batch 897/1661...
# Processing batch 898/1661...
# Processing batch 899/1661...
# Processing batch 900/1661...
# Processing batch 901/1661...
# Processing batch 902/1661...
# Processing batch 903/1661...
# Processing batch 904/1661...
# Processing batch 905/1661...
# Processing batch 906/1661...
# Processing batch 907/1661...
# Processing batch 908/1661...
# Processing batch 909/1661...
# Processing batch 910/1661...
# Processing batch 911/1661...
# Processing batch 912/1661...
# Processing batch 913/1661...
# Processing batch 914/1661...
# Processing batch 915/1661...
# Processing batch 916/1661...
# Processing batch 917/1661...
# Processing batch 918/1661...
# Processing batch 919/1661...
# Processing batch 920/1661...
# Processing batch 921/1661...
# Processing batch 922/1661...
# Processing batch 923/1661...
# Processing batch 924/1661...
# Processing batch 925/1661...
# Processing batch 926/1661...
# Processing batch 927/1661...
# Processing batch 928/1661...
# Processing batch 929/1661...
# Processing batch 930/1661...
# Processing batch 931/1661...
# Processing batch 932/1661...
# Processing batch 933/1661...
# Processing batch 934/1661...
# Processing batch 935/1661...
# Processing batch 936/1661...
# Processing batch 937/1661...
# Processing batch 938/1661...
# Processing batch 939/1661...
# Processing batch 940/1661...
# Processing batch 941/1661...
# Processing batch 942/1661...
# Processing batch 943/1661...
# Processing batch 944/1661...
# Processing batch 945/1661...
# Processing batch 946/1661...
# Processing batch 947/1661...
# Processing batch 948/1661...
# Processing batch 949/1661...
# Processing batch 950/1661...
# Processing batch 951/1661...
# Processing batch 952/1661...
# Processing batch 953/1661...
# Processing batch 954/1661...
# Processing batch 955/1661...
# Processing batch 956/1661...
# Processing batch 957/1661...
# Processing batch 958/1661...
# Processing batch 959/1661...
# Processing batch 960/1661...
# Processing batch 961/1661...
# Processing batch 962/1661...
# Processing batch 963/1661...
# Processing batch 964/1661...
# Processing batch 965/1661...
# Processing batch 966/1661...
# Processing batch 967/1661...
# Processing batch 968/1661...
# Processing batch 969/1661...
# Processing batch 970/1661...
# Processing batch 971/1661...
# Processing batch 972/1661...
# Processing batch 973/1661...
# Processing batch 974/1661...
# Processing batch 975/1661...
# Processing batch 976/1661...
# Processing batch 977/1661...
# Processing batch 978/1661...
# Processing batch 979/1661...
# Processing batch 980/1661...
# Processing batch 981/1661...
# Processing batch 982/1661...
# Processing batch 983/1661...
# Processing batch 984/1661...
# Processing batch 985/1661...
# Processing batch 986/1661...
# Processing batch 987/1661...
# Processing batch 988/1661...
# Processing batch 989/1661...
# Processing batch 990/1661...
# Processing batch 991/1661...
# Processing batch 992/1661...
# Processing batch 993/1661...
# Processing batch 994/1661...
# Processing batch 995/1661...
# Processing batch 996/1661...
# Processing batch 997/1661...
# Processing batch 998/1661...
# Processing batch 999/1661...
# Processing batch 1000/1661...
# Processing batch 1001/1661...
# Processing batch 1002/1661...
# Processing batch 1003/1661...
# Processing batch 1004/1661...
# Processing batch 1005/1661...
# Processing batch 1006/1661...
# Processing batch 1007/1661...
# Processing batch 1008/1661...
# Processing batch 1009/1661...
# Processing batch 1010/1661...
# Processing batch 1011/1661...
# Processing batch 1012/1661...
# Processing batch 1013/1661...
# Processing batch 1014/1661...
# Processing batch 1015/1661...
# Processing batch 1016/1661...
# Processing batch 1017/1661...
# Processing batch 1018/1661...
# Processing batch 1019/1661...
# Processing batch 1020/1661...
# Processing batch 1021/1661...
# Processing batch 1022/1661...
# Processing batch 1023/1661...
# Processing batch 1024/1661...
# Processing batch 1025/1661...
# Processing batch 1026/1661...
# Processing batch 1027/1661...
# Processing batch 1028/1661...
# Processing batch 1029/1661...
# Processing batch 1030/1661...
# Processing batch 1031/1661...
# Processing batch 1032/1661...
# Processing batch 1033/1661...
# Processing batch 1034/1661...
# Processing batch 1035/1661...
# Processing batch 1036/1661...
# Processing batch 1037/1661...
# Processing batch 1038/1661...
# Processing batch 1039/1661...
# Processing batch 1040/1661...
# Processing batch 1041/1661...
# Processing batch 1042/1661...
# Processing batch 1043/1661...
# Processing batch 1044/1661...
# Processing batch 1045/1661...
# Processing batch 1046/1661...
# Processing batch 1047/1661...
# Processing batch 1048/1661...
# Processing batch 1049/1661...
# Processing batch 1050/1661...
# Processing batch 1051/1661...
# Processing batch 1052/1661...
# Processing batch 1053/1661...
# Processing batch 1054/1661...
# Processing batch 1055/1661...
# Processing batch 1056/1661...
# Processing batch 1057/1661...
# Processing batch 1058/1661...
# Processing batch 1059/1661...
# Processing batch 1060/1661...
# Processing batch 1061/1661...
# Processing batch 1062/1661...
# Processing batch 1063/1661...
# Processing batch 1064/1661...
# Processing batch 1065/1661...
# Processing batch 1066/1661...
# Processing batch 1067/1661...
# Processing batch 1068/1661...
# Processing batch 1069/1661...
# Processing batch 1070/1661...
# Processing batch 1071/1661...
# Processing batch 1072/1661...
# Processing batch 1073/1661...
# Processing batch 1074/1661...
# Processing batch 1075/1661...
# Processing batch 1076/1661...
# Processing batch 1077/1661...
# Processing batch 1078/1661...
# Processing batch 1079/1661...
# Processing batch 1080/1661...
# Processing batch 1081/1661...
# Processing batch 1082/1661...
# Processing batch 1083/1661...
# Processing batch 1084/1661...
# Processing batch 1085/1661...
# Processing batch 1086/1661...
# Processing batch 1087/1661...
# Processing batch 1088/1661...
# Processing batch 1089/1661...
# Processing batch 1090/1661...
# Processing batch 1091/1661...
# Processing batch 1092/1661...
# Processing batch 1093/1661...
# Processing batch 1094/1661...
# Processing batch 1095/1661...
# Processing batch 1096/1661...
# Processing batch 1097/1661...
# Processing batch 1098/1661...
# Processing batch 1099/1661...
# Processing batch 1100/1661...
# Processing batch 1101/1661...
# Processing batch 1102/1661...
# Processing batch 1103/1661...
# Processing batch 1104/1661...
# Processing batch 1105/1661...
# Processing batch 1106/1661...
# Processing batch 1107/1661...
# Processing batch 1108/1661...
# Processing batch 1109/1661...
# Processing batch 1110/1661...
# Processing batch 1111/1661...
# Processing batch 1112/1661...
# Processing batch 1113/1661...
# Processing batch 1114/1661...
# Processing batch 1115/1661...
# Processing batch 1116/1661...
# Processing batch 1117/1661...
# Processing batch 1118/1661...
# Processing batch 1119/1661...
# Processing batch 1120/1661...
# Processing batch 1121/1661...
# Processing batch 1122/1661...
# Processing batch 1123/1661...
# Processing batch 1124/1661...
# Processing batch 1125/1661...
# Processing batch 1126/1661...
# Processing batch 1127/1661...
# Processing batch 1128/1661...
# Processing batch 1129/1661...
# Processing batch 1130/1661...
# Processing batch 1131/1661...
# Processing batch 1132/1661...
# Processing batch 1133/1661...
# Processing batch 1134/1661...
# Processing batch 1135/1661...
# Processing batch 1136/1661...
# Processing batch 1137/1661...
# Processing batch 1138/1661...
# Processing batch 1139/1661...
# Processing batch 1140/1661...
# Processing batch 1141/1661...
# Processing batch 1142/1661...
# Processing batch 1143/1661...
# Processing batch 1144/1661...
# Processing batch 1145/1661...
# Processing batch 1146/1661...
# Processing batch 1147/1661...
# Processing batch 1148/1661...
# Processing batch 1149/1661...
# Processing batch 1150/1661...
# Processing batch 1151/1661...
# Processing batch 1152/1661...
# Processing batch 1153/1661...
# Processing batch 1154/1661...
# Processing batch 1155/1661...
# Processing batch 1156/1661...
# Processing batch 1157/1661...
# Processing batch 1158/1661...
# Processing batch 1159/1661...
# Processing batch 1160/1661...
# Processing batch 1161/1661...
# Processing batch 1162/1661...
# Processing batch 1163/1661...
# Processing batch 1164/1661...
# Processing batch 1165/1661...
# Processing batch 1166/1661...
# Processing batch 1167/1661...
# Processing batch 1168/1661...
# Processing batch 1169/1661...
# Processing batch 1170/1661...
# Processing batch 1171/1661...
# Processing batch 1172/1661...
# Processing batch 1173/1661...
# Processing batch 1174/1661...
# Processing batch 1175/1661...
# Processing batch 1176/1661...
# Processing batch 1177/1661...
# Processing batch 1178/1661...
# Processing batch 1179/1661...
# Processing batch 1180/1661...
# Processing batch 1181/1661...
# Processing batch 1182/1661...
# Processing batch 1183/1661...
# Processing batch 1184/1661...
# Processing batch 1185/1661...
# Processing batch 1186/1661...
# Processing batch 1187/1661...
# Processing batch 1188/1661...
# Processing batch 1189/1661...
# Processing batch 1190/1661...
# Processing batch 1191/1661...
# Processing batch 1192/1661...
# Processing batch 1193/1661...
# Processing batch 1194/1661...
# Processing batch 1195/1661...
# Processing batch 1196/1661...
# Processing batch 1197/1661...
# Processing batch 1198/1661...
# Processing batch 1199/1661...
# Processing batch 1200/1661...
# Processing batch 1201/1661...
# Processing batch 1202/1661...
# Processing batch 1203/1661...
# Processing batch 1204/1661...
# Processing batch 1205/1661...
# Processing batch 1206/1661...
# Processing batch 1207/1661...
# Processing batch 1208/1661...
# Processing batch 1209/1661...
# Processing batch 1210/1661...
# Processing batch 1211/1661...
# Processing batch 1212/1661...
# Processing batch 1213/1661...
# Processing batch 1214/1661...
# Processing batch 1215/1661...
# Processing batch 1216/1661...
# Processing batch 1217/1661...
# Processing batch 1218/1661...
# Processing batch 1219/1661...
# Processing batch 1220/1661...
# Processing batch 1221/1661...
# Processing batch 1222/1661...
# Processing batch 1223/1661...
# Processing batch 1224/1661...
# Processing batch 1225/1661...
# Processing batch 1226/1661...
# Processing batch 1227/1661...
# Processing batch 1228/1661...
# Processing batch 1229/1661...
# Processing batch 1230/1661...
# Processing batch 1231/1661...
# Processing batch 1232/1661...
# Processing batch 1233/1661...
# Processing batch 1234/1661...
# Processing batch 1235/1661...
# Processing batch 1236/1661...
# Processing batch 1237/1661...
# Processing batch 1238/1661...
# Processing batch 1239/1661...
# Processing batch 1240/1661...
# Processing batch 1241/1661...
# Processing batch 1242/1661...
# Processing batch 1243/1661...
# Processing batch 1244/1661...
# Processing batch 1245/1661...
# Processing batch 1246/1661...
# Processing batch 1247/1661...
# Processing batch 1248/1661...
# Processing batch 1249/1661...
# Processing batch 1250/1661...
# Processing batch 1251/1661...
# Processing batch 1252/1661...
# Processing batch 1253/1661...
# Processing batch 1254/1661...
# Processing batch 1255/1661...
# Processing batch 1256/1661...
# Processing batch 1257/1661...
# Processing batch 1258/1661...
# Processing batch 1259/1661...
# Processing batch 1260/1661...
# Processing batch 1261/1661...
# Processing batch 1262/1661...
# Processing batch 1263/1661...
# Processing batch 1264/1661...
# Processing batch 1265/1661...
# Processing batch 1266/1661...
# Processing batch 1267/1661...
# Processing batch 1268/1661...
# Processing batch 1269/1661...
# Processing batch 1270/1661...
# Processing batch 1271/1661...
# Processing batch 1272/1661...
# Processing batch 1273/1661...
# Processing batch 1274/1661...
# Processing batch 1275/1661...
# Processing batch 1276/1661...
# Processing batch 1277/1661...
# Processing batch 1278/1661...
# Processing batch 1279/1661...
# Processing batch 1280/1661...
# Processing batch 1281/1661...
# Processing batch 1282/1661...
# Processing batch 1283/1661...
# Processing batch 1284/1661...
# Processing batch 1285/1661...
# Processing batch 1286/1661...
# Processing batch 1287/1661...
# Processing batch 1288/1661...
# Processing batch 1289/1661...
# Processing batch 1290/1661...
# Processing batch 1291/1661...
# Processing batch 1292/1661...
# Processing batch 1293/1661...
# Processing batch 1294/1661...
# Processing batch 1295/1661...
# Processing batch 1296/1661...
# Processing batch 1297/1661...
# Processing batch 1298/1661...
# Processing batch 1299/1661...
# Processing batch 1300/1661...
# Processing batch 1301/1661...
# Processing batch 1302/1661...
# Processing batch 1303/1661...
# Processing batch 1304/1661...
# Processing batch 1305/1661...
# Processing batch 1306/1661...
# Processing batch 1307/1661...
# Processing batch 1308/1661...
# Processing batch 1309/1661...
# Processing batch 1310/1661...
# Processing batch 1311/1661...
# Processing batch 1312/1661...
# Processing batch 1313/1661...
# Processing batch 1314/1661...
# Processing batch 1315/1661...
# Processing batch 1316/1661...
# Processing batch 1317/1661...
# Processing batch 1318/1661...
# Processing batch 1319/1661...
# Processing batch 1320/1661...
# Processing batch 1321/1661...
# Processing batch 1322/1661...
# Processing batch 1323/1661...
# Processing batch 1324/1661...
# Processing batch 1325/1661...
# Processing batch 1326/1661...
# Processing batch 1327/1661...
# Processing batch 1328/1661...
# Processing batch 1329/1661...
# Processing batch 1330/1661...
# Processing batch 1331/1661...
# Processing batch 1332/1661...
# Processing batch 1333/1661...
# Processing batch 1334/1661...
# Processing batch 1335/1661...
# Processing batch 1336/1661...
# Processing batch 1337/1661...
# Processing batch 1338/1661...
# Processing batch 1339/1661...
# Processing batch 1340/1661...
# Processing batch 1341/1661...
# Processing batch 1342/1661...
# Processing batch 1343/1661...
# Processing batch 1344/1661...
# Processing batch 1345/1661...
# Processing batch 1346/1661...
# Processing batch 1347/1661...
# Processing batch 1348/1661...
# Processing batch 1349/1661...
# Processing batch 1350/1661...
# Processing batch 1351/1661...
# Processing batch 1352/1661...
# Processing batch 1353/1661...
# Processing batch 1354/1661...
# Processing batch 1355/1661...
# Processing batch 1356/1661...
# Processing batch 1357/1661...
# Processing batch 1358/1661...
# Processing batch 1359/1661...
# Processing batch 1360/1661...
# Processing batch 1361/1661...
# Processing batch 1362/1661...
# Processing batch 1363/1661...
# Processing batch 1364/1661...
# Processing batch 1365/1661...
# Processing batch 1366/1661...
# Processing batch 1367/1661...
# Processing batch 1368/1661...
# Processing batch 1369/1661...
# Processing batch 1370/1661...
# Processing batch 1371/1661...
# Processing batch 1372/1661...
# Processing batch 1373/1661...
# Processing batch 1374/1661...
# Processing batch 1375/1661...
# Processing batch 1376/1661...
# Processing batch 1377/1661...
# Processing batch 1378/1661...
# Processing batch 1379/1661...
# Processing batch 1380/1661...
# Processing batch 1381/1661...
# Processing batch 1382/1661...
# Processing batch 1383/1661...
# Processing batch 1384/1661...
# Processing batch 1385/1661...
# Processing batch 1386/1661...
# Processing batch 1387/1661...
# Processing batch 1388/1661...
# Processing batch 1389/1661...
# Processing batch 1390/1661...
# Processing batch 1391/1661...
# Processing batch 1392/1661...
# Processing batch 1393/1661...
# Processing batch 1394/1661...
# Processing batch 1395/1661...
# Processing batch 1396/1661...
# Processing batch 1397/1661...
# Processing batch 1398/1661...
# Processing batch 1399/1661...
# Processing batch 1400/1661...
# Processing batch 1401/1661...
# Processing batch 1402/1661...
# Processing batch 1403/1661...
# Processing batch 1404/1661...
# Processing batch 1405/1661...
# Processing batch 1406/1661...
# Processing batch 1407/1661...
# Processing batch 1408/1661...
# Processing batch 1409/1661...
# Processing batch 1410/1661...
# Processing batch 1411/1661...
# Processing batch 1412/1661...
# Processing batch 1413/1661...
# Processing batch 1414/1661...
# Processing batch 1415/1661...
# Processing batch 1416/1661...
# Processing batch 1417/1661...
# Processing batch 1418/1661...
# Processing batch 1419/1661...
# Processing batch 1420/1661...
# Processing batch 1421/1661...
# Processing batch 1422/1661...
# Processing batch 1423/1661...
# Processing batch 1424/1661...
# Processing batch 1425/1661...
# Processing batch 1426/1661...
# Processing batch 1427/1661...
# Processing batch 1428/1661...
# Processing batch 1429/1661...
# Processing batch 1430/1661...
# Processing batch 1431/1661...
# Processing batch 1432/1661...
# Processing batch 1433/1661...
# Processing batch 1434/1661...
# Processing batch 1435/1661...
# Processing batch 1436/1661...
# Processing batch 1437/1661...
# Processing batch 1438/1661...
# Processing batch 1439/1661...
# Processing batch 1440/1661...
# Processing batch 1441/1661...
# Processing batch 1442/1661...
# Processing batch 1443/1661...
# Processing batch 1444/1661...
# Processing batch 1445/1661...
# Processing batch 1446/1661...
# Processing batch 1447/1661...
# Processing batch 1448/1661...
# Processing batch 1449/1661...
# Processing batch 1450/1661...
# Processing batch 1451/1661...
# Processing batch 1452/1661...
# Processing batch 1453/1661...
# Processing batch 1454/1661...
# Processing batch 1455/1661...
# Processing batch 1456/1661...
# Processing batch 1457/1661...
# Processing batch 1458/1661...
# Processing batch 1459/1661...
# Processing batch 1460/1661...
# Processing batch 1461/1661...
# Processing batch 1462/1661...
# Processing batch 1463/1661...
# Processing batch 1464/1661...
# Processing batch 1465/1661...
# Processing batch 1466/1661...
# Processing batch 1467/1661...
# Processing batch 1468/1661...
# Processing batch 1469/1661...
# Processing batch 1470/1661...
# Processing batch 1471/1661...
# Processing batch 1472/1661...
# Processing batch 1473/1661...
# Processing batch 1474/1661...
# Processing batch 1475/1661...
# Processing batch 1476/1661...
# Processing batch 1477/1661...
# Processing batch 1478/1661...
# Processing batch 1479/1661...
# Processing batch 1480/1661...
# Processing batch 1481/1661...
# Processing batch 1482/1661...
# Processing batch 1483/1661...
# Processing batch 1484/1661...
# Processing batch 1485/1661...
# Processing batch 1486/1661...
# Processing batch 1487/1661...
# Processing batch 1488/1661...
# Processing batch 1489/1661...
# Processing batch 1490/1661...
# Processing batch 1491/1661...
# Processing batch 1492/1661...
# Processing batch 1493/1661...
# Processing batch 1494/1661...
# Processing batch 1495/1661...
# Processing batch 1496/1661...
# Processing batch 1497/1661...
# Processing batch 1498/1661...
# Processing batch 1499/1661...
# Processing batch 1500/1661...
# Processing batch 1501/1661...
# Processing batch 1502/1661...
# Processing batch 1503/1661...
# Processing batch 1504/1661...
# Processing batch 1505/1661...
# Processing batch 1506/1661...
# Processing batch 1507/1661...
# Processing batch 1508/1661...
# Processing batch 1509/1661...
# Processing batch 1510/1661...
# Processing batch 1511/1661...
# Processing batch 1512/1661...
# Processing batch 1513/1661...
# Processing batch 1514/1661...
# Processing batch 1515/1661...
# Processing batch 1516/1661...
# Processing batch 1517/1661...
# Processing batch 1518/1661...
# Processing batch 1519/1661...
# Processing batch 1520/1661...
# Processing batch 1521/1661...
# Processing batch 1522/1661...
# Processing batch 1523/1661...
# Processing batch 1524/1661...
# Processing batch 1525/1661...
# Processing batch 1526/1661...
# Processing batch 1527/1661...
# Processing batch 1528/1661...
# Processing batch 1529/1661...
# Processing batch 1530/1661...
# Processing batch 1531/1661...
# Processing batch 1532/1661...
# Processing batch 1533/1661...
# Processing batch 1534/1661...
# Processing batch 1535/1661...
# Processing batch 1536/1661...
# Processing batch 1537/1661...
# Processing batch 1538/1661...
# Processing batch 1539/1661...
# Processing batch 1540/1661...
# Processing batch 1541/1661...
# Processing batch 1542/1661...
# Processing batch 1543/1661...
# Processing batch 1544/1661...
# Processing batch 1545/1661...
# Processing batch 1546/1661...
# Processing batch 1547/1661...
# Processing batch 1548/1661...
# Processing batch 1549/1661...
# Processing batch 1550/1661...
# Processing batch 1551/1661...
# Processing batch 1552/1661...
# Processing batch 1553/1661...
# Processing batch 1554/1661...
# Processing batch 1555/1661...
# Processing batch 1556/1661...
# Processing batch 1557/1661...
# Processing batch 1558/1661...
# Processing batch 1559/1661...
# Processing batch 1560/1661...
# Processing batch 1561/1661...
# Processing batch 1562/1661...
# Processing batch 1563/1661...
# Processing batch 1564/1661...
# Processing batch 1565/1661...
# Processing batch 1566/1661...
# Processing batch 1567/1661...
# Processing batch 1568/1661...
# Processing batch 1569/1661...
# Processing batch 1570/1661...
# Processing batch 1571/1661...
# Processing batch 1572/1661...
# Processing batch 1573/1661...
# Processing batch 1574/1661...
# Processing batch 1575/1661...
# Processing batch 1576/1661...
# Processing batch 1577/1661...
# Processing batch 1578/1661...
# Processing batch 1579/1661...
# Processing batch 1580/1661...
# Processing batch 1581/1661...
# Processing batch 1582/1661...
# Processing batch 1583/1661...
# Processing batch 1584/1661...
# Processing batch 1585/1661...
# Processing batch 1586/1661...
# Processing batch 1587/1661...
# Processing batch 1588/1661...
# Processing batch 1589/1661...
# Processing batch 1590/1661...
# Processing batch 1591/1661...
# Processing batch 1592/1661...
# Processing batch 1593/1661...
# Processing batch 1594/1661...
# Processing batch 1595/1661...
# Processing batch 1596/1661...
# Processing batch 1597/1661...
# Processing batch 1598/1661...
# Processing batch 1599/1661...
# Processing batch 1600/1661...
# Processing batch 1601/1661...
# Processing batch 1602/1661...
# Processing batch 1603/1661...
# Processing batch 1604/1661...
# Processing batch 1605/1661...
# Processing batch 1606/1661...
# Processing batch 1607/1661...
# Processing batch 1608/1661...
# Processing batch 1609/1661...
# Processing batch 1610/1661...
# Processing batch 1611/1661...
# Processing batch 1612/1661...
# Processing batch 1613/1661...
# Processing batch 1614/1661...
# Processing batch 1615/1661...
# Processing batch 1616/1661...
# Processing batch 1617/1661...
# Processing batch 1618/1661...
# Processing batch 1619/1661...
# Processing batch 1620/1661...
# Processing batch 1621/1661...
# Processing batch 1622/1661...
# Processing batch 1623/1661...
# Processing batch 1624/1661...
# Processing batch 1625/1661...
# Processing batch 1626/1661...
# Processing batch 1627/1661...
# Processing batch 1628/1661...
# Processing batch 1629/1661...
# Processing batch 1630/1661...
# Processing batch 1631/1661...
# Processing batch 1632/1661...
# Processing batch 1633/1661...
# Processing batch 1634/1661...
# Processing batch 1635/1661...
# Processing batch 1636/1661...
# Processing batch 1637/1661...
# Processing batch 1638/1661...
# Processing batch 1639/1661...
# Processing batch 1640/1661...
# Processing batch 1641/1661...
# Processing batch 1642/1661...
# Processing batch 1643/1661...
# Processing batch 1644/1661...
# Processing batch 1645/1661...
# Processing batch 1646/1661...
# Processing batch 1647/1661...
# Processing batch 1648/1661...
# Processing batch 1649/1661...
# Processing batch 1650/1661...
# Processing batch 1651/1661...
# Processing batch 1652/1661...
# Processing batch 1653/1661...
# Processing batch 1654/1661...
# Processing batch 1655/1661...
# Processing batch 1656/1661...
# Processing batch 1657/1661...
# Processing batch 1658/1661...
# Processing batch 1659/1661...
# Processing batch 1660/1661...
# Processing batch 1661/1661...
# Rasterizing municipality polygons...
# Exploding polygons...
# Converting to cuDF DataFrame...
# Generating grid of points...
# Creating cuDF DataFrame for points...
# Performing point-in-polygon test...
# Processing batch 1/1...
# Computing flood percentages...

# %%
muni_raster_gpu.shape
# Out:
# (250, 250)

# %%
print("Processing 25-year flood risk data...")
flood_25_percentages = process_flood_risk(gdf_flood_25, gdf_municipality)
print("Processing 100-year flood risk data...")
flood_100_percentages = process_flood_risk(gdf_flood_100, gdf_municipality)

# %%
# import cuspatial
# import cudf
# import geopandas as gpd
# from tqdm import tqdm
# import numpy as np

# def process_flood_risk(gdf_flood):
#     # Convert to cuDF and cuspatial format
#     gdf_flood_cudf = cudf.DataFrame(gdf_flood.drop(columns="geometry"))
#     gdf_flood_cudf["geometry"] = cuspatial.from_geopandas(gdf_flood.geometry)

#     # Split data into smaller chunks (to track progress)
#     # num_chunks = 1024  # Adjust based on GPU memory
#     # chunks = np.array_split(gdf_flood_cudf, num_chunks)

#     # Track progress
#     # results = []
#     # for i, chunk in enumerate(tqdm(chunks, desc="Processing GPU Intersection", unit="batch")):
#     #     result = cuspatial.point_in_polygon(chunk, gdf_municipality)
#     #     results.append(result)

#     # # Merge results
#     # final_result = cudf.concat(results)

#     # final_result = cuspatial.point_in_polygon(gdf_flood_cudf, gdf_municipality)
#     return final_result


# # Process flood risk data
# print("Processing 5-year flood risk data...")
# flood_risk_5 = process_flood_risk(gdf_flood_5)
# print("Processing 25-year flood risk data...")
# flood_risk_25 = process_flood_risk(gdf_flood_25)
# print("Processing 100-year flood risk data...")
# flood_risk_100 = process_flood_risk(gdf_flood_100)

# # Convert results back to GeoPandas
# flood_risk_5 = cuspatial.to_geopandas(flood_risk_5)
# flood_risk_25 = cuspatial.to_geopandas(flood_risk_25)
# flood_risk_100 = cuspatial.to_geopandas(flood_risk_100)

# %%
# # Simplify polygons
# import geopandas as gpd
# import dask_geopandas as dgpd

# # Load GeoDataFrame
# def simplify_polygons(gdf, tolerance=0.001):
#     # Convert to Dask DataFrame
#     ddf = dgpd.from_geopandas(gdf, npartitions=512)  # More partitions for 256 cores

#     # Apply simplification in parallel using map_partitions
#     def simplify_partition(partition):
#         partition = partition.copy()  # Ensure it's a full copy
#         partition.loc[:, "geometry"] = partition["geometry"].simplify(tolerance, preserve_topology=True)
#         return partition
    
#     ddf = ddf.map_partitions(simplify_partition, meta=gdf)

#     # Compute back to GeoDataFrame
#     gdf_simplified = ddf.compute()

#     # Explode only if necessary
#     if gdf_simplified.geometry.geom_type.eq("MultiPolygon").any():
#         gdf_simplified = gdf_simplified.explode(index_parts=False)

#     # Reset index
#     return gdf_simplified.reset_index(drop=True)

# print("Processing 5-year flood risk data...")
# gdf_flood_5 = simplify_polygons(gdf_flood_5)
# print("Processing 25-year flood risk data...")
# gdf_flood_25 = simplify_polygons(gdf_flood_25)
# print("Processing 100-year flood risk data...")
# gdf_flood_100 = simplify_polygons(gdf_flood_100)
# Out:
# Processing 5-year flood risk data...
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# from joblib import Parallel, delayed
# from joblib_progress import joblib_progress

# import geopandas as gpd
# import numpy as np
# import os
# import warnings

# # Function to compute flood risk percentages per municipality
# def compute_flood_percentage(gdf_flood, return_period):
#     # Parallel overlay operation
#     num_partitions = min(128, os.cpu_count() // 2)  # Adjust based on available CPU cores
#     gdf_split = np.array_split(gdf_flood, num_partitions)
    
#     def overlay_partition(subset):
#         with warnings.catch_warnings():
#             warnings.simplefilter("ignore", category=FutureWarning)
#             return gpd.overlay(subset, gdf_municipality, how="intersection", keep_geom_type=False)

#     # Add joblib progress tracking
#     with joblib_progress(f"Computing flood intersection ({return_period}yr)", total=num_partitions):
#         flood_joined_parts = Parallel(n_jobs=num_partitions)(
#             delayed(overlay_partition)(gdf) for gdf in gdf_split
#         )

#     flood_joined = gpd.GeoDataFrame(pd.concat(flood_joined_parts, ignore_index=True))

#     # Compute flooded area per risk level in each municipality
#     flood_joined["flooded_area"] = flood_joined.geometry.area
#     flood_area_by_risk = (
#         flood_joined.groupby(["adm3_psgc", "FloodRisk"])["flooded_area"]
#         .sum()
#         .unstack(fill_value=0)
#     )

#     # Normalize by total municipality area
#     flood_percentage = (flood_area_by_risk.div(municipality_area, axis=0) * 100).fillna(0)
    
#     # Rename columns for clarity
#     flood_percentage = flood_percentage.reset_index()
#     flood_percentage.columns = ["municipality_id", f"%_low_risk_{return_period}yr", f"%_med_risk_{return_period}yr", f"%_high_risk_{return_period}yr"]
    
#     return flood_percentage

# # Compute percentage flood area for different return periods
# flood_5_percentage = compute_flood_percentage(gdf_flood_5, 5)

# %% [markdown]
# ## Merge All Features

# %%
gdf_municipality = gdf_municipality.rename(
    columns={
        "adm3_psgc": "municipality_id",
    }
)

protected_stats = protected_stats.rename(
    columns={
        "Municipality ID": "municipality_id",
    }
)

# %%
# Merge all computed features into the municipality dataframe
final_features = gdf_municipality[["municipality_id"]].merge(landcover_stats, on="municipality_id", how="left")
final_features = final_features.merge(protected_stats, on="municipality_id", how="left")
# final_features = final_features.merge(flood_5_percentage, on="municipality_id", how="left")
# final_features = final_features.merge(flood_25_percentage, on="municipality_id", how="left")
# final_features = final_features.merge(flood_100_percentage, on="municipality_id", how="left")

final_features
# Out:
#      municipality_id  % Forest   % Crops  % Flatlands  % Built-up  % Wetlands  \
# 0       1.028030e+08  0.046231  0.421475     0.443372    0.059711    0.028706
# 1       1.028120e+08  0.000401  0.485153     0.316229    0.147883    0.049561
# 2       1.028150e+08  0.503109  0.137716     0.318179    0.030086    0.009873
# 3       1.028160e+08  0.001565  0.497563     0.376649    0.074523    0.049620
# 4       1.028230e+08  0.190629  0.094527     0.693880    0.008286    0.012678
# ..               ...       ...       ...          ...         ...         ...
# 737     1.908816e+09  0.000000  0.220524     0.001030    0.011617    0.766829
# 738     1.908818e+09  0.000000  0.798091     0.015941    0.047773    0.138195
# 739     1.908820e+09  0.000000  0.854234     0.006270    0.116677    0.022819
# 740     1.908821e+09  0.000000  0.750004     0.113976    0.035925    0.100095
# 741     1.908822e+09  0.037971  0.692691     0.244250    0.017458    0.007631
#
#      % Protected Area
# 0            0.001027
# 1            0.000000
# 2            0.180760
# 3            0.054449
# 4            0.005622
# ..                ...
# 737          0.000000
# 738          0.000000
# 739          0.000000
# 740          0.000000
# 741          0.039427
#
# [742 rows x 7 columns]

# %%
final_features.to_parquet("model_features.parquet", index=False)
