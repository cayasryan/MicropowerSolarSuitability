# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd

tags = {
    'place': 'settlement',
    'place': 'village',
    'type': 'indigenous',
    'ethnicity': 'indigenous',
}

# Query both residential land use and residential buildings for the Philippines
ip_areas = ox.features_from_place("Philippines", tags=tags)
# Out:
# /data/students/ryan/anaconda3/envs/capstone_venv/lib/python3.13/site-packages/osmnx/_overpass.py:267: UserWarning: This area is 638 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)

# %%
ip_areas # NONE
# Out:
#                                                              geometry  \
# element id
# node    25679280                           POINT (123.67632 12.97423)
#         25679305                           POINT (123.69412 13.01002)
#         25679310                           POINT (123.71542 13.03364)
#         25679347                           POINT (123.71185 13.05237)
#         25679367                           POINT (123.57894 12.92291)
# ...                                                               ...
# way     1384002729  POLYGON ((125.10112 6.17814, 125.09814 6.18102...
#         1384002730  POLYGON ((125.09356 6.16318, 125.09336 6.16451...
#         1384002730  POLYGON ((125.09356 6.16318, 125.09336 6.16451...
#         1384249346  POLYGON ((125.0724 6.17065, 125.07256 6.16969,...
#         1384249346  POLYGON ((125.0724 6.17065, 125.07256 6.16969,...
#
#                    admin_level admin_type:PH is_in:province is_in:town  \
# element id
# node    25679280           NaN           NaN       Sorsogon     Donsol
#         25679305           NaN           NaN       Sorsogon      Pilar
#         25679310           NaN           NaN       Sorsogon      Pilar
#         25679347           NaN           NaN            NaN        NaN
#         25679367           NaN           NaN       Sorsogon     Donsol
# ...                        ...           ...            ...        ...
# way     1384002729         NaN           NaN            NaN        NaN
#         1384002730         NaN           NaN            NaN        NaN
#         1384002730         NaN           NaN            NaN        NaN
#         1384249346         NaN           NaN            NaN        NaN
#         1384249346         NaN           NaN            NaN        NaN
#
#                                   name old_ref    place place:PH population  \
# element id
# node    25679280              San Jose     NaN  village      NaN        NaN
#         25679305                Poctol     NaN  village      NaN        NaN
#         25679310                Danlog     NaN  village      NaN        NaN
#         25679347                   NaN     NaN  village      NaN        NaN
#         25679367              Dancalan     NaN  village      NaN        NaN
# ...                                ...     ...      ...      ...        ...
# way     1384002729   Purok 2B. Moninio     NaN  village      NaN        NaN
#         1384002730  Purok 3C. Cutamora     NaN  village      NaN        NaN
#         1384002730  Purok 3C. Cutamora     NaN  village      NaN        NaN
#         1384249346            Purok 7.     NaN  village      NaN        NaN
#         1384249346            Purok 7.     NaN  village      NaN        NaN
#
#                     ... fine:cycleway:right fine:foot fine:oneway  \
# element id          ...
# node    25679280    ...                 NaN       NaN         NaN
#         25679305    ...                 NaN       NaN         NaN
#         25679310    ...                 NaN       NaN         NaN
#         25679347    ...                 NaN       NaN         NaN
#         25679367    ...                 NaN       NaN         NaN
# ...                 ...                 ...       ...         ...
# way     1384002729  ...                 NaN       NaN         NaN
#         1384002730  ...                 NaN       NaN         NaN
#         1384002730  ...                 NaN       NaN         NaN
#         1384249346  ...                 NaN       NaN         NaN
#         1384249346  ...                 NaN       NaN         NaN
#
#                    fine:parking:both:restriction fine:smoking operator  \
# element id
# node    25679280                             NaN          NaN      NaN
#         25679305                             NaN          NaN      NaN
#         25679310                             NaN          NaN      NaN
#         25679347                             NaN          NaN      NaN
#         25679367                             NaN          NaN      NaN
# ...                                          ...          ...      ...
# way     1384002729                           NaN          NaN      NaN
#         1384002730                           NaN          NaN      NaN
#         1384002730                           NaN          NaN      NaN
#         1384249346                           NaN          NaN      NaN
#         1384249346                           NaN          NaN      NaN
#
#                    operator:type wheelchair addr:country source:geometry
# element id
# node    25679280             NaN        NaN          NaN             NaN
#         25679305             NaN        NaN          NaN             NaN
#         25679310             NaN        NaN          NaN             NaN
#         25679347             NaN        NaN          NaN             NaN
#         25679367             NaN        NaN          NaN             NaN
# ...                          ...        ...          ...             ...
# way     1384002729           NaN        NaN          NaN             NaN
#         1384002730           NaN        NaN          NaN             NaN
#         1384002730           NaN        NaN          NaN             NaN
#         1384249346           NaN        NaN          NaN             NaN
#         1384249346           NaN        NaN          NaN             NaN
#
# [26404 rows x 184 columns]
